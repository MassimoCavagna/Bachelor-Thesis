# %%
import pandas as pd
import numpy as np
import math
import datetime
from ipynb.fs.defs.Local_search import new_route
from ipynb.fs.defs.Local_search import get_row
from ipynb.fs.defs.Local_search import get_column
from ipynb.fs.defs.Local_search import best_index
from ipynb.fs.defs.Local_search import schedule_time
from ipynb.fs.defs.Local_search import find_best_position
from ipynb.fs.defs.Local_search import cities_list
#table=pd.read_csv("../Dati/orari/route.csv", delimiter=";")
#time_table=pd.read_csv("../Dati/orari/route_time.csv", delimiter=";")
dft = pd.read_csv("../Dati/distanze/times_computed.csv", delimiter=";", encoding = "ISO-8859-1", index_col=0)
#dfd = pd.read_csv("../Dati/distanze/distances_computed.csv", delimiter=";", encoding = "ISO-8859-1", index_col=0)
#fur1 = pd.read_csv("../Dati/turni_f/furgoncino1_routing.csv", delimiter=";", encoding = "ISO-8859-1")
#fur2 = pd.read_csv("../Dati/turni_f/furgoncino2_routing.csv", delimiter=";", encoding = "ISO-8859-1")
#fur1d = pd.read_csv("../Dati/turni_f/furgoncino1_KM_routing.csv", delimiter=";", encoding = "ISO-8859-1")
#fur2d = pd.read_csv("../Dati/turni_f/furgoncino2_KM_routing.csv", delimiter=";", encoding = "ISO-8859-1")
fur1 = pd.read_csv("../Dati/turni_f/2-opt1_shifts.csv", delimiter=";", encoding = "ISO-8859-1")
fur2 = pd.read_csv("../Dati/turni_f/2-opt2_shifts.csv", delimiter=";", encoding = "ISO-8859-1")

# %%
#Given a list of cities it return False if "to_insert" is already present
#Return True if "to_insert" isn't present and it will give the index of the best position
def check_insert(schedule_day_list, to_insert, dframe):
    if to_insert in schedule_day_list:
        return False, -1
    else:
        #print(schedule_day_list)
        schedule_day_list = cities_list(new_route(schedule_day_list, dframe))
        to_return = best_index(schedule_day_list, new_route(schedule_day_list, dframe), to_insert, dframe)
        return True, to_return

#Given: city list wich to_insert come, the city "to_insert" to be moved, 
#the city list where "to_insert" will be insered, the index of the best position and a dataframe
#the function return the improvement
#If negative the exchange mustn't be done, if positive you gain some time
def improvement(f_l, to_insert, t_l, index, dframe):
    from_list = f_l[:]
    from_time = sum(new_route(from_list, dframe).values)
    from_list.remove(to_insert)
    from_time_removed = sum(new_route(from_list, dframe).values)
    
    to_list = t_l[:]
    to_time = sum(new_route(to_list, dframe).values)
    to_list.insert(index, to_insert)
    to_time_insert = sum(new_route(to_list, dframe).values)
    
    return (from_time-from_time_removed) + (to_time-to_time_insert)

# %%
l = list(fur1["lunedi"].dropna())
m = list(fur1["martedi"].dropna())
i = l[3]
b, pos = check_insert(m, i, dft)
if b:
    print(improvement(l, i, m, pos,dft))
# Out:
# ['Cremona, Sesto 39', 'Cremona, Ugolani Dati, 4', 'Casalpusterlengo, Pusterla 7', 'Vailate, Dante Alighieri, 7', 'Crema, Civerchi, 9', 'Persico Dosimo, Albert ,7', 'Scandolara Ravara, Italia', 'Casalmaggiore, Guglielmo Marconi, 8', 'San Giovanni in Croce, Feudatari, 25 A', 'Ostiano, Mazzini, 1', 'Ostiano, Mazzini, 1']
# 11.0

# %%
def get_best_improvement(days, veichle, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_f_list):
    for inner_day in days:
        if(veichle==1):
            curr_to_list = list(fur1[inner_day].dropna())
        else:
            curr_to_list = list(fur2[inner_day].dropna())
           
        if inner_day == day:
            continue
        else:
            boo, index = check_insert(curr_to_list, to_insert, dft)

        if boo:
            local_improvement = improvement(curr_f_list, to_insert, curr_to_list, index, dft)
        else:
            continue

        #If there's an improvement we update "best" variables, in other case we skip to next day
        if local_improvement<0:
            continue
        elif local_improvement>best_improvement:
            best_improvement = local_improvement
            best_day = inner_day
            best_veichle = veichle
            best_idx = index
        else:
            continue
    return best_improvement, best_day, best_veichle, best_idx

# %%
#For every day of every veichle we get every Location
#We compare the improvement removing this location from the day/veichle routing list and inserting it 
#in the other day/veichle routing lists.
#The location will be moved only if the improvement is positive 
#In case of different positive improvement we move in the higher
week = ["lunedi", "martedi", "mercoledi", "giovedi", "venerdi"]
short_week = ["martedi", "mercoledi", "giovedi"]
fur1_copy = fur1.copy()
fur2_copy = fur2.copy()
for day in week:
    curr_from_list = list(fur1_copy[day].dropna())
    to_insert_list = list(fur1_copy[day].dropna())
    cycles = len(to_insert_list)
    #For every location in this schedule
    for i in range(1, cycles-1):
        print(to_insert_list)
        to_insert = to_insert_list.pop(i)
        
        #to_insert = to_insert_list.pop(0)
        
        best_improvement = -1000
        best_day = ""
        best_veichle = ""
        best_idx = ""
        #Here we must compare every possible insert in other days
        #Cycle for first veichle
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(week, 1, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list)
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(short_week, 2, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list)
        #If best_day isn't modified where isn't an improvement for every day/veihe
        if(best_day==""):
            continue
        else:
            #Remove from origin list and insert into target list
            curr_from_list.remove(to_insert)
            if(best_veichle==1):
                temp_list = list(fur1[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #fur1_copy[best_day] = pd.Series(temp_list)
                fur1_copy[best_day] =  fur1_copy[best_day].replace(fur1_copy[best_day], pd.Series(temp_list))
            elif(best_veichle==2):
                temp_list = list(fur2[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #fur2_copy[best_day] = pd.Series(temp_list)
                fur2_copy[best_day] =  fur2_copy[best_day].replace(fur2_copy[best_day], pd.Series(temp_list))
fur1_copy
# Out:
# ['Cremona, Sesto 39', 'Sesto ed Uniti, Roma, 4', 'Grumello Cremonese ed Uniti, Roma, 2', 'Pizzighettone, Giuseppe Garibaldi, 18', 'Castelleone, Roma, 67', 'Montodine,  XXV Aprile, 10', 'Ripalta Cremasca, Roma, 5', 'Ricengo, Guglielmo Marconi', 'Capralba, Piave, 2', 'Sergnano, IV Novembre,  10', 'Casale Cremasco', 'Camisano, Trieste, 57', 'Soncino, Dante Alighieri, 23', 'Trigolo, Roma, 26', 'Soresina, Giacomo Matteotti, 6', 'Ostiano, Mazzini, 1']
# ['Cremona, Sesto 39', 'Cremona, Ugolani Dati, 4', 'Pizzighettone, Giuseppe Garibaldi, 18', 'Casalpusterlengo, Pusterla 7', 'Vailate, Dante Alighieri, 7', 'Crema, Civerchi, 9', 'Persico Dosimo, Albert ,7', 'Scandolara Ravara, Italia', 'Casalmaggiore, Guglielmo Marconi, 8', 'San Giovanni in Croce, Feudatari, 25 A', 'Ostiano, Mazzini, 1', 'Ostiano, Mazzini, 1']
# ['Cremona, sesto 39', 'Castelverde', 'Annicco', 'Castelleone', 'Madignano', 'Crema', 'Palazzo Pignano', 'Pandino', "Rivolta D'adda", "Spino d'adda", 'Romanengo', 'Ostiano, Mazzini, 1', 'Ostiano']
# ['Cremona, Sesto 39', 'Cremona, Sesto 39', 'Cremona, Ugolani Dati, 4', 'Persico Dosimo, Albert ,7', 'Grontardo, Roma, 16', 'Vescovato, Roma, 44', 'Crema, Civerchi, 9', 'Offanengo, Clavelli Martini, 5', 'Izano, Gerardo da Izano, 4/C', 'Manerbio, INSURREZIONE NAZIONALE', 'Casalmaggiore, Guglielmo Marconi, 8', 'San Giovanni in Croce, Feudatari, 25 A', 'Piadena, Platina, 40', 'Isola Dovarese, Giacomo Matteotti, 1', 'Ostiano, Mazzini, 1', 'Ostiano, Mazzini, 1']
# ['Cremona, Sesto 39', 'Crema, Civerchi, 9', 'Casaletto Vaprio, Maggiore, 7', 'Trescore Cremasco, Vittorio Veneto, 1', 'Pandino, Castello, 15', 'Agnadello, Marconi, 6', "Rivolta d'Adda, Stefano Renzi, 5", "Spino d'Adda, Circonvallazione, 13", 'Dovera, Oldrini 2', 'Monte Cremasco, Roma, 12', 'Vaiano Cremasco,  Gloriosi Caduti, 3', 'Bagnolo Cremasco, Roma, 3', 'Capergnanica, XI febbraio, 7', 'Ostiano, Mazzini, 1']
# ['Cremona, Sesto 39', 'Cremona, Felice Cavallotti, 2', 'Pianengo, Nenni', 'Ricengo, Guglielmo Marconi', 'Offanengo, Clavelli Martini, 5', 'Manerbio, INSURREZIONE NAZIONALE', 'Bonemerse, Roma, 25', 'Sospiro, Tosi', 'Gadesco', 'Vescovato, Roma, 44', 'Pescarolo ed Uniti, Giuseppe Mazzini, 73', 'Piadena, Platina, 40', 'Rivarolo del Re ed Uniti, Giovanni XXIII, 5', 'Viadana, A. Manzoni, 2', 'Gussola, Comaschi, 1', 'Solarolo Rainerio, Giuseppina, 81']
# ['Cremona, Sesto 39', 'Cremona, Palosca n. 2', 'Paderno Ponchielli, Municipio, 3', 'San Bassano, Mons. Frosi', 'Trigolo, Roma, 26', 'Fiesco, Giuseppe Parini, 10', 'Soncino, Dante Alighieri, 23', 'Soresina, Giacomo Matteotti, 6', 'Casalbuttano ed Uniti, Jacini, 23', 'San Giovanni in Croce, Feudatari, 25 A']
# ['Cremona, Sesto 39', 'Cremona, Ugolani Dati, 4', 'Pizzighettone, Giuseppe Garibaldi, 18', 'Gadesco', 'Pescarolo ed Uniti, Giuseppe Mazzini, 73', "Cingia de' Botti, Giuseppina, 79", 'Martignana di Po, LibertÃ\xa0, 64', 'Solarolo Rainerio, Giuseppina, 81', 'San Giovanni in Croce, Feudatari, 25 A']
# ['Cremona, Sesto 39', 'Grumello Cremonese ed Uniti, Roma, 2', 'Pizzighettone, Giuseppe Garibaldi, 18', 'Castelleone, Roma, 67', 'Montodine,  XXV Aprile, 10', 'Ripalta Cremasca, Roma, 5', 'Ricengo, Guglielmo Marconi', 'Capralba, Piave, 2', 'Sergnano, IV Novembre,  10', 'Casale Cremasco', 'Camisano, Trieste, 57', 'Soncino, Dante Alighieri, 23', 'Trigolo, Roma, 26', 'Soresina, Giacomo Matteotti, 6', 'Ostiano, Mazzini, 1']
# ['Cremona, sesto 39', 'Castelverde', 'Annicco', 'Castelleone', 'Madignano', 'Crema', 'Palazzo Pignano', 'Pandino', "Rivolta D'adda", "Spino d'adda", 'Romanengo', 'Ostiano, Mazzini, 1', 'Ostiano']
# ['Cremona, Sesto 39', 'Cremona, Sesto 39', 'Cremona, Ugolani Dati, 4', 'Persico Dosimo, Albert ,7', 'Grontardo, Roma, 16', 'Vescovato, Roma, 44', 'Crema, Civerchi, 9', 'Offanengo, Clavelli Martini, 5', 'Izano, Gerardo da Izano, 4/C', 'Manerbio, INSURREZIONE NAZIONALE', 'Casalmaggiore, Guglielmo Marconi, 8', 'San Giovanni in Croce, Feudatari, 25 A', 'Piadena, Platina, 40', 'Isola Dovarese, Giacomo Matteotti, 1', 'Ostiano, Mazzini, 1', 'Ostiano, Mazzini, 1']
# ['Cremona, Sesto 39', 'Crema, Civerchi, 9', 'Casaletto Vaprio, Maggiore, 7', 'Trescore Cremasco, Vittorio Veneto, 1', 'Pandino, Castello, 15', 'Agnadello, Marconi, 6', "Rivolta d'Adda, Stefano Renzi, 5", "Spino d'Adda, Circonvallazione, 13", 'Dovera, Oldrini 2', 'Monte Cremasco, Roma, 12', 'Vaiano Cremasco,  Gloriosi Caduti, 3', 'Bagnolo Cremasco, Roma, 3', 'Capergnanica, XI febbraio, 7', 'Ostiano, Mazzini, 1']
# ['Cremona, Sesto 39', 'Cremona, Felice Cavallotti, 2', 'Pianengo, Nenni', 'Ricengo, Guglielmo Marconi', 'Offanengo, Clavelli Martini, 5', 'Manerbio, INSURREZIONE NAZIONALE', 'Bonemerse, Roma, 25', 'Sospiro, Tosi', 'Gadesco', 'Vescovato, Roma, 44', 'Pescarolo ed Uniti, Giuseppe Mazzini, 73', 'Piadena, Platina, 40', 'Rivarolo del Re ed Uniti, Giovanni XXIII, 5', 'Viadana, A. Manzoni, 2', 'Gussola, Comaschi, 1', 'Solarolo Rainerio, Giuseppina, 81']
# ['Cremona, Sesto 39', 'Cremona, Palosca n. 2', 'Paderno Ponchielli, Municipio, 3', 'San Bassano, Mons. Frosi', 'Trigolo, Roma, 26', 'Fiesco, Giuseppe Parini, 10', 'Soncino, Dante Alighieri, 23', 'Soresina, Giacomo Matteotti, 6', 'Casalbuttano ed Uniti, Jacini, 23', 'San Giovanni in Croce, Feudatari, 25 A']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-a1e55c923bc8> in <module>
#      37                 temp_list.insert(best_idx, to_insert)
#      38                 #fur1_copy[best_day] = pd.Series(temp_list)
# ---> 39                 fur1_copy[best_day] =  fur1_copy[best_day].replace(fur1_copy[best_day], pd.Series(temp_list))
#      40             elif(best_veichle==2):
#      41                 temp_list = list(fur2[best_day].dropna())
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3843         return super(Series, self).replace(to_replace=to_replace, value=value,
#    3844                                            inplace=inplace, limit=limit,
# -> 3845                                            regex=regex, method=method)
#    3846
#    3847     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6515                                                     value=value[c],
#    6516                                                     inplace=False,
# -> 6517                                                     regex=regex)
#    6518                     return None if inplace else res
#    6519
#
# TypeError: replace() takes no keyword arguments

# %%
print(cycles)
# Out:
# 16

# %%
fur1
# Out:
#                                    lunedi  \
# 0                       Cremona, Sesto 39
# 1                 Sesto ed Uniti, Roma, 4
# 2    Grumello Cremonese ed Uniti, Roma, 2
# 3   Pizzighettone, Giuseppe Garibaldi, 18
# 4                   Castelleone, Roma, 67
# 5              Montodine,  XXV Aprile, 10
# 6               Ripalta Cremasca, Roma, 5
# 7              Ricengo, Guglielmo Marconi
# 8                      Capralba, Piave, 2
# 9              Sergnano, IV Novembre,  10
# 10                        Casale Cremasco
# 11                  Camisano, Trieste, 57
# 12           Soncino, Dante Alighieri, 23
# 13                      Trigolo, Roma, 26
# 14         Soresina, Giacomo Matteotti, 6
# 15                    Ostiano, Mazzini, 1
#
#                                    martedi            mercoledi  \
# 0                        Cremona, Sesto 39    Cremona, sesto 39
# 1                 Cremona, Ugolani Dati, 4          Castelverde
# 2    Pizzighettone, Giuseppe Garibaldi, 18              Annicco
# 3             Casalpusterlengo, Pusterla 7          Castelleone
# 4              Vailate, Dante Alighieri, 7            Madignano
# 5                       Crema, Civerchi, 9                Crema
# 6                Persico Dosimo, Albert ,7      Palazzo Pignano
# 7                Scandolara Ravara, Italia              Pandino
# 8      Casalmaggiore, Guglielmo Marconi, 8       Rivolta D'adda
# 9   San Giovanni in Croce, Feudatari, 25 A         Spino d'adda
# 10                     Ostiano, Mazzini, 1            Romanengo
# 11                     Ostiano, Mazzini, 1  Ostiano, Mazzini, 1
# 12                                     NaN              Ostiano
# 13                                     NaN                  NaN
# 14                                     NaN                  NaN
# 15                                     NaN                  NaN
#
#                                    giovedi  \
# 0                        Cremona, Sesto 39
# 1                        Cremona, Sesto 39
# 2                 Cremona, Ugolani Dati, 4
# 3                Persico Dosimo, Albert ,7
# 4                      Grontardo, Roma, 16
# 5                      Vescovato, Roma, 44
# 6                       Crema, Civerchi, 9
# 7           Offanengo, Clavelli Martini, 5
# 8             Izano, Gerardo da Izano, 4/C
# 9         Manerbio, INSURREZIONE NAZIONALE
# 10     Casalmaggiore, Guglielmo Marconi, 8
# 11  San Giovanni in Croce, Feudatari, 25 A
# 12                    Piadena, Platina, 40
# 13    Isola Dovarese, Giacomo Matteotti, 1
# 14                     Ostiano, Mazzini, 1
# 15                     Ostiano, Mazzini, 1
#
#                                   venerdi
# 0                       Cremona, Sesto 39
# 1                      Crema, Civerchi, 9
# 2           Casaletto Vaprio, Maggiore, 7
# 3   Trescore Cremasco, Vittorio Veneto, 1
# 4                   Pandino, Castello, 15
# 5                   Agnadello, Marconi, 6
# 6        Rivolta d'Adda, Stefano Renzi, 5
# 7      Spino d'Adda, Circonvallazione, 13
# 8                       Dovera, Oldrini 2
# 9                Monte Cremasco, Roma, 12
# 10   Vaiano Cremasco,  Gloriosi Caduti, 3
# 11              Bagnolo Cremasco, Roma, 3
# 12           Capergnanica, XI febbraio, 7
# 13                    Ostiano, Mazzini, 1
# 14                                    NaN
# 15                                    NaN
