# %%
import pandas as pd
import numpy as np
import math
import datetime
from ipynb.fs.defs.Local_search import new_route
from ipynb.fs.defs.Local_search import get_row
from ipynb.fs.defs.Local_search import get_column
from ipynb.fs.defs.Local_search import best_index
from ipynb.fs.defs.Local_search import schedule_time
from ipynb.fs.defs.Local_search import find_best_position
from ipynb.fs.defs.Local_search import cities_list
#table=pd.read_csv("../Dati/orari/route.csv", delimiter=";")
#time_table=pd.read_csv("../Dati/orari/route_time.csv", delimiter=";")
dft = pd.read_csv("../Dati/distanze/times_computed.csv", delimiter=";", encoding = "ISO-8859-1", index_col=0)
#dfd = pd.read_csv("../Dati/distanze/distances_computed.csv", delimiter=";", encoding = "ISO-8859-1", index_col=0)
#fur1 = pd.read_csv("../Dati/turni_f/furgoncino1_routing.csv", delimiter=";", encoding = "ISO-8859-1")
#fur2 = pd.read_csv("../Dati/turni_f/furgoncino2_routing.csv", delimiter=";", encoding = "ISO-8859-1")
#fur1d = pd.read_csv("../Dati/turni_f/furgoncino1_KM_routing.csv", delimiter=";", encoding = "ISO-8859-1")
#fur2d = pd.read_csv("../Dati/turni_f/furgoncino2_KM_routing.csv", delimiter=";", encoding = "ISO-8859-1")
fur1 = pd.read_csv("../Dati/turni_f/2-opt1_shifts.csv", delimiter=";", encoding = "ISO-8859-1")
fur2 = pd.read_csv("../Dati/turni_f/2-opt2_shifts.csv", delimiter=";", encoding = "ISO-8859-1")

# %% [raw]
# padding = pd.Series([np.nan*(len(fur1)-len(cities_list(new_route(fur1["mercoledi"].dropna(), dft))))])
# temp_list = pd.concat([pd.Series(cities_list(new_route(fur1["mercoledi"].dropna(), dft))), padding], ignore_index=True)
# fur1["mercoledi"] = temp_list
# fur1.to_csv("../Dati/turni_f/2-opt1_shifts.csv", sep=";", index=False)

# %% [raw]
# fur1 = pd.read_csv("../Dati/turni_f/2-opt1_shifts.csv", delimiter=";", encoding = "ISO-8859-1")
# fur1

# %% [raw]
# fur2

# %%
#Given a list of cities it return False if "to_insert" is already present
#Return True if "to_insert" isn't present and it will give the index of the best position
def check_insert(schedule_day_list, to_insert, dframe):
    if to_insert in schedule_day_list:
        return False, -1
    else:
        #schedule_day_list = cities_list(new_route(schedule_day_list, dframe))
        to_return = best_index(schedule_day_list, new_route(schedule_day_list, dframe), to_insert, dframe)
        return True, to_return

#Given: city list wich to_insert come, the city "to_insert" to be moved, 
#the city list where "to_insert" will be insered, the index of the best position and a dataframe
#the function return the improvement
#If negative the exchange mustn't be done, if positive you gain some time
def improvement(f_l, to_insert, t_l, index, dframe):
    from_list = f_l[:]
    from_time = sum(new_route(from_list, dframe).values)
    from_list.remove(to_insert)
    from_time_removed = sum(new_route(from_list, dframe).values)
    
    to_list = t_l[:]
    to_time = sum(new_route(to_list, dframe).values)
    try:
        to_list.insert(index, to_insert)
    except:
        print(to_list)
    to_time_insert = sum(new_route(to_list, dframe).values)
    
    return (from_time-from_time_removed) + (to_time-to_time_insert)

# %%
schedule_day_list = ['Cremona, Sesto 39', 'Cremona, Ugolani Dati, 4', 'Cremona, Felice Cavallotti, 2', 'Pianengo, Nenni', 'Sergnano, IV Novembre,  10', 'Camisano, Trieste, 57', 'Casale Cremasco-Vidolasco, Roma, 56', 'Ricengo, Guglielmo Marconi', 'Offanengo, Clavelli Martini, 5', 'Manerbio, INSURREZIONE NAZIONALE', 'Bonemerse, Roma, 25', 'Sospiro, Tosi', 'Gadesco-Pieve Delmona, Giovanni Lonati 9', 'Vescovato, Roma, 44', 'Pescarolo ed Uniti, Giuseppe Mazzini, 73', 'Piadena, Platina, 40', 'Rivarolo del Re ed Uniti, Giovanni XXIII, 5', 'Viadana, A. Manzoni, 2', 'Gussola, Comaschi, 1', 'Solarolo Rainerio, Giuseppina, 81', 'San Giovanni in Croce, Feudatari, 25 A']
isasf=best_index(schedule_day_list, new_route(schedule_day_list, dft), "Persico Dosimo, Albert ,7", dft)
print(isasf)
# Out:
# 13

# %%
l = list(fur1["lunedi"].dropna())
m = list(fur1["martedi"].dropna())
i = l[3]
b, pos = check_insert(m, i, dft)
if b:
    print(improvement(l, i, m, pos,dft))
# Out:
# 11.0

# %%
def get_best_improvement(curr_day, veichle, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_f_list, fur1_copy, fur2_copy):
    local_improvement = ""
    if(veichle==1):
        days = ["lunedi", "martedi", "mercoledi", "giovedi", "venerdi"]
    else:
        days = ["martedi", "mercoledi", "giovedi"]
        
    for inner_day in days:
        if(veichle==1):
            curr_to_list = list(fur1_copy[inner_day].dropna())
        else:
            curr_to_list = list(fur2_copy[inner_day].dropna())
           
        #print(inner_day)
        if inner_day == curr_day:
            #print("continua")
            continue
        else:
            boo, index = check_insert(curr_to_list, to_insert, dft)
        if boo:
            local_improvement = improvement(curr_f_list, to_insert, curr_to_list, index, dft)
        else:
            continue

        #If there's an improvement we update "best" variables, in other case we skip to next day
        #print(local_improvement)
        if local_improvement<0:
            continue
        elif local_improvement>best_improvement:
            best_improvement = local_improvement
            best_day = inner_day
            best_veichle = veichle
            best_idx = index
        else:
            continue
    return best_improvement, best_day, best_veichle, best_idx

# %%
#For every day of every veichle we get every Location
#We compare the improvement removing this location from the day/veichle routing list and inserting it 
#in the other day/veichle routing lists.
#The location will be moved only if the improvement is positive 
#In case of different positive improvement we move in the higher
pudding = 25
week = ["lunedi", "martedi", "mercoledi", "giovedi", "venerdi"]
short_week = ["martedi", "mercoledi", "giovedi"]
fur1_copy = pd.DataFrame({})
fur1_copy['col'] = pd.Series([0]*pudding)
fur1_copy = fur1_copy.join(fur1)

fur2_copy = pd.DataFrame({})
fur2_copy['col'] = pd.Series([0]*pudding)
fur2_copy = fur2_copy.join(fur2)

for day in week:
    #day="lunedi"
    print(day, end="###\n")
    curr_from_list = list(fur1_copy[day].dropna())
    to_insert_list = list(fur1_copy[day].dropna())
    #print(to_insert_list)
    #to_insert_list.remove("Ostiano, Mazzini, 1")
    #curr_from_list.remove("Ostiano, Mazzini, 1")
    cycles = len(to_insert_list)
    #For every location in this schedule
    for i in range(1, cycles-1):
        #print(to_insert_list)
        to_insert = to_insert_list.pop(0)
        #print(to_insert, end=", ")
        #to_insert = to_insert_list.pop(0)

        best_improvement = -1000
        best_day = ""
        best_veichle = ""
        best_idx = ""
        #Here we must compare every possible insert in other days
        #Cycle for first veichle
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(day, 1, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(day, 2, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)

        #If best_day isn't modified where isn't an improvement for every day/veichle
        if(best_day==""):
            continue
        else:
            #Remove from origin list and insert into target list
            curr_from_list.remove(to_insert)
            
            if(best_veichle==1):
                #print(f"{to_insert} miglioramento veicolo 1 a {best_day}")
                temp_list = list(fur1_copy[best_day].dropna())
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur1_copy[best_day] = fur1_copy[best_day].replace(list(fur1_copy[best_day]), temp_list)
                fur1_copy[best_day] = pd.Series(temp_list).values

            elif(best_veichle==2):
                #print(f"{to_insert} miglioramento veicolo 2 a {best_day}")
                temp_list = list(fur2_copy[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur2_copy[best_day] =  fur2_copy[best_day].replace(list(fur2_copy[best_day]), temp_list)
                fur2_copy[best_day] = pd.Series(temp_list).values
    padding = pd.Series([np.nan]*(pudding-len(curr_from_list)))
    curr_from_list = pd.concat([pd.Series(curr_from_list), padding], ignore_index=True)
    fur1_copy[day] = pd.Series(curr_from_list).values
fur1_copy
# Out:
# lunedi###
# martedi###
# mercoledi###
# giovedi###
# venerdi###
#     col                                lunedi  \
# 0     0                     Cremona, Sesto 39
# 1     0               Sesto ed Uniti, Roma, 4
# 2     0  Grumello Cremonese ed Uniti, Roma, 2
# 3     0            Montodine,  XXV Aprile, 10
# 4     0             Ripalta Cremasca, Roma, 5
# 5     0          Soncino, Dante Alighieri, 23
# 6     0        Soresina, Giacomo Matteotti, 6
# 7     0                   Ostiano, Mazzini, 1
# 8     0                                   NaN
# 9     0                                   NaN
# 10    0                                   NaN
# 11    0                                   NaN
# 12    0                                   NaN
# 13    0                                   NaN
# 14    0                                   NaN
# 15    0                                   NaN
# 16    0                                   NaN
# 17    0                                   NaN
# 18    0                                   NaN
# 19    0                                   NaN
# 20    0                                   NaN
# 21    0                                   NaN
# 22    0                                   NaN
# 23    0                                   NaN
# 24    0                                   NaN
#
#                                    martedi  \
# 0                        Cremona, Sesto 39
# 1                Persico Dosimo, Albert ,7
# 2                Scandolara Ravara, Italia
# 3   San Giovanni in Croce, Feudatari, 25 A
# 4                      Ostiano, Mazzini, 1
# 5                      Ostiano, Mazzini, 1
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
#
#                              mercoledi  \
# 0                    Cremona, Sesto 39
# 1      Castelverde, Ubaldo Ferrari, 15
# 2       Annicco, Giuseppe Garibaldi, 6
# 3                Castelleone, Roma, 67
# 4                Madignano, Portici, 4
# 5            Bagnolo Cremasco, Roma, 3
# 6      Palazzo Pignano, Marco Polo, 31
# 7                Pandino, Castello, 15
# 8     Rivolta d'Adda, Stefano Renzi, 5
# 9   Spino d'Adda, Circonvallazione, 13
# 10            Romanengo, Guaiarini, 14
# 11                 Ostiano, Mazzini, 1
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
#
#                                    giovedi  \
# 0                        Cremona, Sesto 39
# 1                        Cremona, Sesto 39
# 2                Persico Dosimo, Albert ,7
# 3                      Vescovato, Roma, 44
# 4   San Giovanni in Croce, Feudatari, 25 A
# 5                     Piadena, Platina, 40
# 6                      Ostiano, Mazzini, 1
# 7                      Ostiano, Mazzini, 1
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
#
#                                   venerdi
# 0                       Cremona, Sesto 39
# 1                      Crema, Civerchi, 9
# 2           Casaletto Vaprio, Maggiore, 7
# 3   Trescore Cremasco, Vittorio Veneto, 1
# 4                   Pandino, Castello, 15
# 5        Rivolta d'Adda, Stefano Renzi, 5
# 6      Spino d'Adda, Circonvallazione, 13
# 7                       Dovera, Oldrini 2
# 8                Monte Cremasco, Roma, 12
# 9    Vaiano Cremasco,  Gloriosi Caduti, 3
# 10              Bagnolo Cremasco, Roma, 3
# 11           Capergnanica, XI febbraio, 7
# 12                    Ostiano, Mazzini, 1
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN

# %%
fur2_copy
# Out:
#     col                                      martedi  \
# 0     0                            Cremona, Sesto 39
# 1     0                     Cremona, Ugolani Dati, 4
# 2     0                Cremona, Felice Cavallotti, 2
# 3     0                              Pianengo, Nenni
# 4     0                   Sergnano, IV Novembre,  10
# 5     0                        Camisano, Trieste, 57
# 6     0          Casale Cremasco-Vidolasco, Roma, 56
# 7     0                   Ricengo, Guglielmo Marconi
# 8     0               Offanengo, Clavelli Martini, 5
# 9     0             Manerbio, INSURREZIONE NAZIONALE
# 10    0                          Bonemerse, Roma, 25
# 11    0                                Sospiro, Tosi
# 12    0     Gadesco-Pieve Delmona, Giovanni Lonati 9
# 13    0                          Vescovato, Roma, 44
# 14    0     Pescarolo ed Uniti, Giuseppe Mazzini, 73
# 15    0         Isola Dovarese, Giacomo Matteotti, 1
# 16    0                         Piadena, Platina, 40
# 17    0  Rivarolo del Re ed Uniti, Giovanni XXIII, 5
# 18    0                       Viadana, A. Manzoni, 2
# 19    0                         Gussola, Comaschi, 1
# 20    0          Casalmaggiore, Guglielmo Marconi, 8
# 21    0            Solarolo Rainerio, Giuseppina, 81
# 22    0       San Giovanni in Croce, Feudatari, 25 A
# 23    0                                          NaN
# 24    0                                          NaN
#
#                                  mercoledi  \
# 0                        Cremona, Sesto 39
# 1                 Cremona, Ugolani Dati, 4
# 2                    Cremona, Palosca n. 2
# 3         Paderno Ponchielli, Municipio, 3
# 4                 San Bassano, Mons. Frosi
# 5                    Castelleone, Roma, 67
# 6              Fiesco, Giuseppe Parini, 10
# 7             Soncino, Dante Alighieri, 23
# 8           Soresina, Giacomo Matteotti, 6
# 9        Casalbuttano ed Uniti, Jacini, 23
# 10  San Giovanni in Croce, Feudatari, 25 A
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
#
#                                      giovedi
# 0                          Cremona, Sesto 39
# 1                   Cremona, Ugolani Dati, 4
# 2      Pizzighettone, Giuseppe Garibaldi, 18
# 3   Gadesco-Pieve Delmona, Giovanni Lonati 9
# 4   Pescarolo ed Uniti, Giuseppe Mazzini, 73
# 5           Cingia de' Botti, Giuseppina, 79
# 6              Martignana di Po, Libertà, 64
# 7        Casalmaggiore, Guglielmo Marconi, 8
# 8          Solarolo Rainerio, Giuseppina, 81
# 9     San Giovanni in Croce, Feudatari, 25 A
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN

# %%
#For every day of every veichle we get every Location
#We compare the improvement removing this location from the day/veichle routing list and inserting it 
#in the other day/veichle routing lists.
#The location will be moved only if the improvement is positive 
#In case of different positive improvement we move in the higher
pudding = 25

for day in short_week:
    #day="lunedi"
    print(day, end="###\n")
    curr_from_list = list(fur2_copy[day].dropna())
    to_insert_list = list(fur2_copy[day].dropna())
    #print(to_insert_list)
    #to_insert_list.remove("Ostiano, Mazzini, 1")
    #curr_from_list.remove("Ostiano, Mazzini, 1")
    cycles = len(to_insert_list)
    #For every location in this schedule
    for i in range(1, cycles-1):
        #print(to_insert_list)
        to_insert = to_insert_list.pop(0)
        #print(to_insert, end=", ")
        #to_insert = to_insert_list.pop(0)

        best_improvement = -1000
        best_day = ""
        best_veichle = ""
        best_idx = ""
        #Here we must compare every possible insert in other days
        #Cycle for first veichle
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(day, 1, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(day, 2, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)

        #If best_day isn't modified where isn't an improvement for every day/veichle
        if(best_day==""):
            continue
        else:
            #Remove from origin list and insert into target list
            curr_from_list.remove(to_insert)
            
            if(best_veichle==1):
                #print(f"{to_insert} miglioramento veicolo 1 a {best_day}")
                temp_list = list(fur1_copy[best_day].dropna())
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur1_copy[best_day] = fur1_copy[best_day].replace(list(fur1_copy[best_day]), temp_list)
                fur1_copy[best_day] = pd.Series(temp_list).values

            elif(best_veichle==2):
                #print(f"{to_insert} miglioramento veicolo 2 a {best_day}")
                temp_list = list(fur2_copy[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur2_copy[best_day] =  fur2_copy[best_day].replace(list(fur2_copy[best_day]), temp_list)
                fur2_copy[best_day] = pd.Series(temp_list).values
    padding = pd.Series([np.nan]*(pudding-len(curr_from_list)))
    curr_from_list = pd.concat([pd.Series(curr_from_list), padding], ignore_index=True)
    fur2_copy[day] = pd.Series(curr_from_list).values
fur2_copy
# Out:
# martedi###
# mercoledi###
# giovedi###
#     col                                      martedi  \
# 0     0                            Cremona, Sesto 39
# 1     0                Cremona, Felice Cavallotti, 2
# 2     0                     Cremona, Ugolani Dati, 4
# 3     0                              Pianengo, Nenni
# 4     0                   Sergnano, IV Novembre,  10
# 5     0                        Camisano, Trieste, 57
# 6     0          Casale Cremasco-Vidolasco, Roma, 56
# 7     0                   Ricengo, Guglielmo Marconi
# 8     0                          Bonemerse, Roma, 25
# 9     0  Rivarolo del Re ed Uniti, Giovanni XXIII, 5
# 10    0                       Viadana, A. Manzoni, 2
# 11    0          Casalmaggiore, Guglielmo Marconi, 8
# 12    0            Solarolo Rainerio, Giuseppina, 81
# 13    0       San Giovanni in Croce, Feudatari, 25 A
# 14    0                                          NaN
# 15    0                                          NaN
# 16    0                                          NaN
# 17    0                                          NaN
# 18    0                                          NaN
# 19    0                                          NaN
# 20    0                                          NaN
# 21    0                                          NaN
# 22    0                                          NaN
# 23    0                                          NaN
# 24    0                                          NaN
#
#                                  mercoledi  \
# 0                        Cremona, Sesto 39
# 1                 Cremona, Ugolani Dati, 4
# 2         Paderno Ponchielli, Municipio, 3
# 3                 San Bassano, Mons. Frosi
# 4                    Castelleone, Roma, 67
# 5              Fiesco, Giuseppe Parini, 10
# 6             Soncino, Dante Alighieri, 23
# 7           Soresina, Giacomo Matteotti, 6
# 8        Casalbuttano ed Uniti, Jacini, 23
# 9                     Piadena, Platina, 40
# 10  San Giovanni in Croce, Feudatari, 25 A
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
#
#                                      giovedi
# 0                          Cremona, Sesto 39
# 1   Gadesco-Pieve Delmona, Giovanni Lonati 9
# 2                        Vescovato, Roma, 44
# 3                              Sospiro, Tosi
# 4           Cingia de' Botti, Giuseppina, 79
# 5              Martignana di Po, Libertà, 64
# 6                       Gussola, Comaschi, 1
# 7        Casalmaggiore, Guglielmo Marconi, 8
# 8          Solarolo Rainerio, Giuseppina, 81
# 9     San Giovanni in Croce, Feudatari, 25 A
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN

# %%
fur1_copy.to_csv("../Dati/turni_f/multi_veich_LS1.csv", sep=";", index=False)
fur2_copy.to_csv("../Dati/turni_f/multi_veich_LS2.csv", sep=";", index=False)

# %%
fur2_copy = pd.DataFrame({})
fur2_copy['col'] = pd.Series([np.nan]*50)
fur2_copy = fur2_copy.join(fur2)
fur2_copy[["martedi", "mercoledi", "giovedi"]]

# %%
a=pd.Series(["a","b","c"])
b=pd.Series([np.nan]*(10-len(a)))
pd.concat([a,b], ignore_index=True)

# %%
fur1_copy = pd.DataFrame({})
fur1_copy['col'] = pd.Series([0]*50)
fur1_copy = fur1_copy.join(fur1)
temp_list = pd.Series(["ciao"])
padding=pd.Series([np.nan]*(50-len(temp_list)))
temp_list = pd.concat([temp_list, padding], ignore_index=True)
fur1_copy[best_day] = fur1_copy[best_day].replace(list(fur1_copy[best_day]), temp_list)
