# %%
import pandas as pd
import numpy as np
import math
import datetime
from ipynb.fs.defs.functions import new_route
from ipynb.fs.defs.functions import get_row
from ipynb.fs.defs.functions import get_column
from ipynb.fs.defs.functions import best_index
from ipynb.fs.defs.functions import find_best_position
from ipynb.fs.defs.functions import cities_list
from ipynb.fs.defs.functions import getName

dft = pd.read_csv("../Dati/distanze/times_computed.csv", delimiter=";", encoding = "ISO-8859-1", index_col=0)
fur1 = pd.read_csv("../Dati/turni_f/2-opt1_shifts.csv", delimiter=";", encoding = "ISO-8859-1")
fur2 = pd.read_csv("../Dati/turni_f/2-opt2_shifts.csv", delimiter=";", encoding = "ISO-8859-1")

# %%
column = [getName(dft, x) for x in fur1["mercoledi"].dropna()]
pad = pd.Series([np.nan]*(len(fur1)-len(column)))
column = pd.concat([pd.Series(column), pad], ignore_index=True)
fur1["mercoledi"] = column

# %%
fur1
# Out:
#                                    lunedi  \
# 0                       Cremona, Sesto 39
# 1                 Sesto ed Uniti, Roma, 4
# 2    Grumello Cremonese ed Uniti, Roma, 2
# 3   Pizzighettone, Giuseppe Garibaldi, 18
# 4                   Castelleone, Roma, 67
# 5              Montodine,  XXV Aprile, 10
# 6               Ripalta Cremasca, Roma, 5
# 7              Ricengo, Guglielmo Marconi
# 8                      Capralba, Piave, 2
# 9              Sergnano, IV Novembre,  10
# 10    Casale Cremasco-Vidolasco, Roma, 56
# 11                  Camisano, Trieste, 57
# 12           Soncino, Dante Alighieri, 23
# 13                      Trigolo, Roma, 26
# 14         Soresina, Giacomo Matteotti, 6
# 15                    Ostiano, Mazzini, 1
#
#                                    martedi  \
# 0                        Cremona, Sesto 39
# 1                 Cremona, Ugolani Dati, 4
# 2             Casalpusterlengo, Pusterla 7
# 3              Vailate, Dante Alighieri, 7
# 4                       Crema, Civerchi, 9
# 5                Persico Dosimo, Albert ,7
# 6                Scandolara Ravara, Italia
# 7      Casalmaggiore, Guglielmo Marconi, 8
# 8   San Giovanni in Croce, Feudatari, 25 A
# 9                      Ostiano, Mazzini, 1
# 10                     Ostiano, Mazzini, 1
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
#
#                              mercoledi  \
# 0                    Cremona, Sesto 39
# 1      Castelverde, Ubaldo Ferrari, 15
# 2       Annicco, Giuseppe Garibaldi, 6
# 3                Castelleone, Roma, 67
# 4                Madignano, Portici, 4
# 5                   Crema, Civerchi, 9
# 6      Palazzo Pignano, Marco Polo, 31
# 7                Pandino, Castello, 15
# 8     Rivolta d'Adda, Stefano Renzi, 5
# 9   Spino d'Adda, Circonvallazione, 13
# 10            Romanengo, Guaiarini, 14
# 11                 Ostiano, Mazzini, 1
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
#
#                                    giovedi  \
# 0                        Cremona, Sesto 39
# 1                        Cremona, Sesto 39
# 2                 Cremona, Ugolani Dati, 4
# 3                Persico Dosimo, Albert ,7
# 4                      Grontardo, Roma, 16
# 5                      Vescovato, Roma, 44
# 6                       Crema, Civerchi, 9
# 7           Offanengo, Clavelli Martini, 5
# 8             Izano, Gerardo da Izano, 4/C
# 9         Manerbio, INSURREZIONE NAZIONALE
# 10     Casalmaggiore, Guglielmo Marconi, 8
# 11  San Giovanni in Croce, Feudatari, 25 A
# 12                    Piadena, Platina, 40
# 13    Isola Dovarese, Giacomo Matteotti, 1
# 14                     Ostiano, Mazzini, 1
# 15                     Ostiano, Mazzini, 1
#
#                                   venerdi
# 0                       Cremona, Sesto 39
# 1                      Crema, Civerchi, 9
# 2           Casaletto Vaprio, Maggiore, 7
# 3   Trescore Cremasco, Vittorio Veneto, 1
# 4                   Pandino, Castello, 15
# 5                   Agnadello, Marconi, 6
# 6        Rivolta d'Adda, Stefano Renzi, 5
# 7      Spino d'Adda, Circonvallazione, 13
# 8                       Dovera, Oldrini 2
# 9                Monte Cremasco, Roma, 12
# 10   Vaiano Cremasco,  Gloriosi Caduti, 3
# 11              Bagnolo Cremasco, Roma, 3
# 12           Capergnanica, XI febbraio, 7
# 13                    Ostiano, Mazzini, 1
# 14                                    NaN
# 15                                    NaN

# %%
#Given a list of cities it return False if "to_insert" is already present
#Return True if "to_insert" isn't present and it will give the index of the best position
def check_insert(schedule_day_list, to_insert, dframe):
    if to_insert in list(schedule_day_list.dropna()):
        return False, -1
    else:
        #schedule_day_list = cities_list(new_route(schedule_day_list, dframe))
        to_return = best_index(schedule_day_list, new_route(schedule_day_list, dframe), to_insert, dframe)
        return True, to_return

#Given: city list wich to_insert come, the city "to_insert" to be moved, 
#the city list where "to_insert" will be insered, the index of the best position and a dataframe
#the function return the improvement
#If negative the exchange mustn't be done, if positive you gain some time
def improvement(f_l, to_insert, t_l, index, dframe):
    from_list = f_l[:]
    from_time = sum(new_route(from_list, dframe).values)
    from_list.remove(to_insert)
    from_time_removed = sum(new_route(from_list, dframe).values)
    
    to_list = t_l[:]
    to_time = sum(new_route(to_list, dframe).values)
    try:
        to_list.insert(index, to_insert)
    except:
        print(to_list)
    to_time_insert = sum(new_route(to_list, dframe).values)
    
    return (from_time-from_time_removed) + (to_time-to_time_insert)

# %%
def get_best_improvement(curr_day, from_vehicle, to_vehicle, best_improvement, best_day, best_vehicle, best_idx, to_insert, curr_f_list, fur1_copy, fur2_copy):
    local_improvement = ""
    if(to_vehicle==1):
        days = ["lunedi", "martedi", "mercoledi", "giovedi", "venerdi"]
    else:
        days = ["martedi", "mercoledi", "giovedi"]
        
    for inner_day in days:
        if(to_vehicle==1):
            curr_to_list = list(fur1_copy[inner_day].dropna())
        else:
            curr_to_list = list(fur2_copy[inner_day].dropna())
           
        #print(inner_day)
        if inner_day == curr_day and from_vehicle == to_vehicle:
            #print("continua")
            continue
        else:
            boo, index = check_insert(curr_to_list, to_insert, dft)
        if boo:
            local_improvement = improvement(curr_f_list, to_insert, curr_to_list, index, dft)
        else:
            continue

        #If there's an improvement we update "best" variables, in other case we skip to next day
        #print(local_improvement)
        if local_improvement=="":
            continue
        elif local_improvement>best_improvement:
            best_improvement = local_improvement
            best_day = inner_day
            best_vehicle = to_vehicle
            best_idx = index
        else:
            continue
    return best_improvement, best_day, best_vehicle, best_idx

# %%
#For every day of every veichle we get every Location
#We compare the improvement removing this location from the day/veichle routing list and inserting it 
#in the other day/veichle routing lists.
#The location will be moved only if the improvement is positive 
#In case of different positive improvement we move in the higher
pudding = 50
week = ["lunedi", "martedi", "mercoledi", "giovedi", "venerdi"]
short_week = ["martedi", "mercoledi", "giovedi"]
fur1_copy = pd.DataFrame({})
fur1_copy['col'] = pd.Series([0]*pudding)
fur1_copy = fur1_copy.join(fur1)

fur2_copy = pd.DataFrame({})
fur2_copy['col'] = pd.Series([0]*pudding)
fur2_copy = fur2_copy.join(fur2)

for day in week:
    #day="lunedi"
    print(day, end="###\n")
    curr_from_list = list(fur1_copy[day].dropna())
    to_insert_list = list(fur1_copy[day].dropna())
    #print(to_insert_list)
    #to_insert_list.remove("Ostiano, Mazzini, 1")
    #curr_from_list.remove("Ostiano, Mazzini, 1")
    cycles = len(to_insert_list)
    #For every location in this schedule
    for i in range(1, cycles-1):
        #print(to_insert_list)
        to_insert = to_insert_list.pop(0)
        #print(to_insert, end=", ")

        best_improvement = -1000
        best_day = ""
        best_vehicle = ""
        best_idx = ""
        #Here we must compare every possible insert in other days
        #Cycle for first veichle
        best_improvement, best_day, best_vehicle, best_idx = get_best_improvement(day, 1, 1, best_improvement, best_day, best_vehicle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)
        best_improvement, best_day, best_vehicle, best_idx = get_best_improvement(day, 1, 2, best_improvement, best_day, best_vehicle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)

        #If best_day isn't modified where isn't an improvement for every day/veichle
        if(best_improvement==-1000):
            continue
        else:
            #Remove from origin list and insert into target list
            curr_from_list.remove(to_insert)
            
            if(best_vehicle==1):
                #print(f"{to_insert} miglioramento veicolo 1 a {best_day}")
                temp_list = list(fur1_copy[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur1_copy[best_day] = fur1_copy[best_day].replace(list(fur1_copy[best_day]), temp_list)
                fur1_copy[best_day] = pd.Series(temp_list).values

            elif(best_vehicle==2):
                #print(f"{to_insert} miglioramento veicolo 2 a {best_day}")
                temp_list = list(fur2_copy[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur2_copy[best_day] =  fur2_copy[best_day].replace(list(fur2_copy[best_day]), temp_list)
                fur2_copy[best_day] = pd.Series(temp_list).values
    padding = pd.Series([np.nan]*(pudding-len(curr_from_list)))
    curr_from_list = pd.concat([pd.Series(curr_from_list), padding], ignore_index=True)
    fur1_copy[day] = pd.Series(curr_from_list).values
fur1_copy
# Out:
# lunedi###
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-d9272330d863> in <module>
#      36         #Here we must compare every possible insert in other days
#      37         #Cycle for first veichle
# ---> 38         best_improvement, best_day, best_vehicle, best_idx = get_best_improvement(day, 1, 1, best_improvement, best_day, best_vehicle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)
#      39         best_improvement, best_day, best_vehicle, best_idx = get_best_improvement(day, 1, 2, best_improvement, best_day, best_vehicle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)
#      40
#
# <ipython-input-63-21841463ba6a> in get_best_improvement(curr_day, from_vehicle, to_vehicle, best_improvement, best_day, best_vehicle, best_idx, to_insert, curr_f_list, fur1_copy, fur2_copy)
#      17             continue
#      18         else:
# ---> 19             boo, index = check_insert(curr_to_list, to_insert, dft)
#      20         if boo:
#      21             local_improvement = improvement(curr_f_list, to_insert, curr_to_list, index, dft)
#
# <ipython-input-62-f09bdb938ae1> in check_insert(schedule_day_list, to_insert, dframe)
#       2 #Return True if "to_insert" isn't present and it will give the index of the best position
#       3 def check_insert(schedule_day_list, to_insert, dframe):
# ----> 4     if to_insert in list(schedule_day_list.dropna()):
#       5         return False, -1
#       6     else:
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
#For every day of every veichle we get every Location
#We compare the improvement removing this location from the day/veichle routing list and inserting it 
#in the other day/veichle routing lists.
#The location will be moved only if the improvement is positive 
#In case of different positive improvement we move in the higher
pudding = 50

for day in short_week:
    #day="lunedi"
    print(day, end="###\n")
    curr_from_list = list(fur2_copy[day].dropna())
    to_insert_list = list(fur2_copy[day].dropna())
    #print(to_insert_list)
    #to_insert_list.remove("Ostiano, Mazzini, 1")
    #curr_from_list.remove("Ostiano, Mazzini, 1")
    cycles = len(to_insert_list)
    #For every location in this schedule
    for i in range(1, cycles-1):
        #print(to_insert_list)
        to_insert = to_insert_list.pop(0)
        #print(to_insert, end=", ")
        #to_insert = to_insert_list.pop(0)

        best_improvement = -1000
        best_day = ""
        best_veichle = ""
        best_idx = ""
        #Here we must compare every possible insert in other days
        #Cycle for first veichle
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(day, 2, 1, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)
        best_improvement, best_day, best_veichle, best_idx = get_best_improvement(day, 2, 2, best_improvement, best_day, best_veichle, best_idx, to_insert, curr_from_list, fur1_copy, fur2_copy)

        #If best_day isn't modified where isn't an improvement for every day/veichle
        if(best_improvement==-1000):
            continue
        else:
            #Remove from origin list and insert into target list
            curr_from_list.remove(to_insert)
            
            if(best_veichle==1):
                #print(f"{to_insert} miglioramento veicolo 1 a {best_day}")
                temp_list = list(fur1_copy[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur1_copy[best_day] = fur1_copy[best_day].replace(list(fur1_copy[best_day]), temp_list)
                fur1_copy[best_day] = pd.Series(temp_list).values

            elif(best_veichle==2):
                #print(f"{to_insert} miglioramento veicolo 2 a {best_day}")
                temp_list = list(fur2_copy[best_day].dropna())
                temp_list.insert(best_idx, to_insert)
                temp_list.insert(best_idx, to_insert)
                #temp_list.append("Ostiano, Mazzini, 1")
                padding = pd.Series([np.nan]*(pudding-len(temp_list)))
                temp_list = pd.concat([pd.Series(temp_list), padding], ignore_index=True)
                #fur2_copy[best_day] =  fur2_copy[best_day].replace(list(fur2_copy[best_day]), temp_list)
                fur2_copy[best_day] = pd.Series(temp_list).values
    padding = pd.Series([np.nan]*(pudding-len(curr_from_list)))
    curr_from_list = pd.concat([pd.Series(curr_from_list), padding], ignore_index=True)
    fur2_copy[day] = pd.Series(curr_from_list).values
fur2_copy
# Out:
# martedi###
# mercoledi###
# giovedi###
#     col                                 martedi  \
# 0     0                       Cremona, Sesto 39
# 1     0                      Crema, Civerchi, 9
# 2     0                      Crema, Civerchi, 9
# 3     0                Cremona, Ugolani Dati, 4
# 4     0                Cremona, Ugolani Dati, 4
# 5     0       Solarolo Rainerio, Giuseppina, 81
# 6     0  San Giovanni in Croce, Feudatari, 25 A
# 7     0                                     NaN
# 8     0                                     NaN
# 9     0                                     NaN
# 10    0                                     NaN
# 11    0                                     NaN
# 12    0                                     NaN
# 13    0                                     NaN
# 14    0                                     NaN
# 15    0                                     NaN
# 16    0                                     NaN
# 17    0                                     NaN
# 18    0                                     NaN
# 19    0                                     NaN
# 20    0                                     NaN
# 21    0                                     NaN
# 22    0                                     NaN
# 23    0                                     NaN
# 24    0                                     NaN
# 25    0                                     NaN
# 26    0                                     NaN
# 27    0                                     NaN
# 28    0                                     NaN
# 29    0                                     NaN
# 30    0                                     NaN
# 31    0                                     NaN
# 32    0                                     NaN
# 33    0                                     NaN
# 34    0                                     NaN
# 35    0                                     NaN
# 36    0                                     NaN
# 37    0                                     NaN
# 38    0                                     NaN
# 39    0                                     NaN
# 40    0                                     NaN
# 41    0                                     NaN
# 42    0                                     NaN
# 43    0                                     NaN
# 44    0                                     NaN
# 45    0                                     NaN
# 46    0                                     NaN
# 47    0                                     NaN
# 48    0                                     NaN
# 49    0                                     NaN
#
#                                  mercoledi  \
# 0                        Cremona, Sesto 39
# 1                       Crema, Civerchi, 9
# 2                       Crema, Civerchi, 9
# 3                 Cremona, Ugolani Dati, 4
# 4                 Cremona, Ugolani Dati, 4
# 5      Casalmaggiore, Guglielmo Marconi, 8
# 6                   Viadana, A. Manzoni, 2
# 7                   Viadana, A. Manzoni, 2
# 8                     Gussola, Comaschi, 1
# 9                     Gussola, Comaschi, 1
# 10  San Giovanni in Croce, Feudatari, 25 A
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                                     NaN
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
# 44                                     NaN
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
# 48                                     NaN
# 49                                     NaN
#
#                                    giovedi
# 0                        Cremona, Sesto 39
# 1        Solarolo Rainerio, Giuseppina, 81
# 2   San Giovanni in Croce, Feudatari, 25 A
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
# 32                                     NaN
# 33                                     NaN
# 34                                     NaN
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                                     NaN
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43                                     NaN
# 44                                     NaN
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
# 48                                     NaN
# 49                                     NaN

# %%
fur1_copy
# Out:
#     col                                       lunedi  \
# 0     0                            Cremona, Sesto 39
# 1     0                 Casalpusterlengo, Pusterla 7
# 2     0        Pizzighettone, Giuseppe Garibaldi, 18
# 3     0                      Sesto ed Uniti, Roma, 4
# 4     0         Grumello Cremonese ed Uniti, Roma, 2
# 5     0                     San Bassano, Mons. Frosi
# 6     0                        Castelleone, Roma, 67
# 7     0                        Madignano, Portici, 4
# 8     0                 Izano, Gerardo da Izano, 4/C
# 9     0                            Trigolo, Roma, 26
# 10    0                  Fiesco, Giuseppe Parini, 10
# 11    0                 Soncino, Dante Alighieri, 23
# 12    0               Offanengo, Clavelli Martini, 5
# 13    0                           Crema, Civerchi, 9
# 14    0               Soresina, Giacomo Matteotti, 6
# 15    0       San Giovanni in Croce, Feudatari, 25 A
# 16    0  Rivarolo del Re ed Uniti, Giovanni XXIII, 5
# 17    0                Martignana di Po, Libertà, 64
# 18    0                         Gussola, Comaschi, 1
# 19    0                       Viadana, A. Manzoni, 2
# 20    0          Casalmaggiore, Guglielmo Marconi, 8
# 21    0                    Scandolara Ravara, Italia
# 22    0             Cingia de' Botti, Giuseppina, 79
# 23    0                         Piadena, Platina, 40
# 24    0         Isola Dovarese, Giacomo Matteotti, 1
# 25    0                                Sospiro, Tosi
# 26    0     Pescarolo ed Uniti, Giuseppe Mazzini, 73
# 27    0                          Ostiano, Mazzini, 1
# 28    0                                          NaN
# 29    0                                          NaN
# 30    0                                          NaN
# 31    0                                          NaN
# 32    0                                          NaN
# 33    0                                          NaN
# 34    0                                          NaN
# 35    0                                          NaN
# 36    0                                          NaN
# 37    0                                          NaN
# 38    0                                          NaN
# 39    0                                          NaN
# 40    0                                          NaN
# 41    0                                          NaN
# 42    0                                          NaN
# 43    0                                          NaN
# 44    0                                          NaN
# 45    0                                          NaN
# 46    0                                          NaN
# 47    0                                          NaN
# 48    0                                          NaN
# 49    0                                          NaN
#
#                                      martedi  \
# 0                          Cremona, Sesto 39
# 1              Cremona, Felice Cavallotti, 2
# 2                        Bonemerse, Roma, 25
# 3                              Sospiro, Tosi
# 4                      Cremona, Palosca n. 2
# 5   Gadesco-Pieve Delmona, Giovanni Lonati 9
# 6                  Persico Dosimo, Albert ,7
# 7                   Cremona, Ugolani Dati, 4
# 8           Manerbio, INSURREZIONE NAZIONALE
# 9                        Ostiano, Mazzini, 1
# 10                       Ostiano, Mazzini, 1
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39                                       NaN
# 40                                       NaN
# 41                                       NaN
# 42                                       NaN
# 43                                       NaN
# 44                                       NaN
# 45                                       NaN
# 46                                       NaN
# 47                                       NaN
# 48                                       NaN
# 49                                       NaN
#
#                                       mercoledi              giovedi  \
# 0                             Cremona, Sesto 39    Cremona, Sesto 39
# 1              Manerbio, INSURREZIONE NAZIONALE    Cremona, Sesto 39
# 2                      Cremona, Ugolani Dati, 4  Ostiano, Mazzini, 1
# 3             Casalbuttano ed Uniti, Jacini, 23  Ostiano, Mazzini, 1
# 4               Castelverde, Ubaldo Ferrari, 15                  NaN
# 5                            Crema, Civerchi, 9                  NaN
# 6                            Capralba, Piave, 2                  NaN
# 7                   Vailate, Dante Alighieri, 7                  NaN
# 8                 Casaletto Vaprio, Maggiore, 7                  NaN
# 9         Trescore Cremasco, Vittorio Veneto, 1                  NaN
# 10           Spino d'Adda, Circonvallazione, 13                  NaN
# 11             Rivolta d'Adda, Stefano Renzi, 5                  NaN
# 12                        Agnadello, Marconi, 6                  NaN
# 13                            Dovera, Oldrini 2                  NaN
# 14                        Pandino, Castello, 15                  NaN
# 15                              Pianengo, Nenni                  NaN
# 16                        Camisano, Trieste, 57                  NaN
# 17          Casale Cremasco-Vidolasco, Roma, 56                  NaN
# 18                   Sergnano, IV Novembre,  10                  NaN
# 19                   Ricengo, Guglielmo Marconi                  NaN
# 20               Offanengo, Clavelli Martini, 5                  NaN
# 21                 Soncino, Dante Alighieri, 23                  NaN
# 22                     Romanengo, Guaiarini, 14                  NaN
# 23                          Grontardo, Roma, 16                  NaN
# 24                    Persico Dosimo, Albert ,7                  NaN
# 25     Gadesco-Pieve Delmona, Giovanni Lonati 9                  NaN
# 26                          Vescovato, Roma, 44                  NaN
# 27       San Giovanni in Croce, Feudatari, 25 A                  NaN
# 28  Rivarolo del Re ed Uniti, Giovanni XXIII, 5                  NaN
# 29          Casalmaggiore, Guglielmo Marconi, 8                  NaN
# 30                         Piadena, Platina, 40                  NaN
# 31                          Ostiano, Mazzini, 1                  NaN
# 32                                          NaN                  NaN
# 33                                          NaN                  NaN
# 34                                          NaN                  NaN
# 35                                          NaN                  NaN
# 36                                          NaN                  NaN
# 37                                          NaN                  NaN
# 38                                          NaN                  NaN
# 39                                          NaN                  NaN
# 40                                          NaN                  NaN
# 41                                          NaN                  NaN
# 42                                          NaN                  NaN
# 43                                          NaN                  NaN
# 44                                          NaN                  NaN
# 45                                          NaN                  NaN
# 46                                          NaN                  NaN
# 47                                          NaN                  NaN
# 48                                          NaN                  NaN
# 49                                          NaN                  NaN
#
#                                      venerdi
# 0                          Cremona, Sesto 39
# 1                  Persico Dosimo, Albert ,7
# 2             Annicco, Giuseppe Garibaldi, 6
# 3             Soresina, Giacomo Matteotti, 6
# 4           Paderno Ponchielli, Municipio, 3
# 5      Pizzighettone, Giuseppe Garibaldi, 18
# 6                      Castelleone, Roma, 67
# 7                 Montodine,  XXV Aprile, 10
# 8                  Ripalta Cremasca, Roma, 5
# 9             Offanengo, Clavelli Martini, 5
# 10                        Crema, Civerchi, 9
# 11             Casaletto Vaprio, Maggiore, 7
# 12           Palazzo Pignano, Marco Polo, 31
# 13                 Bagnolo Cremasco, Roma, 3
# 14                  Monte Cremasco, Roma, 12
# 15      Vaiano Cremasco,  Gloriosi Caduti, 3
# 16                     Pandino, Castello, 15
# 17        Spino d'Adda, Circonvallazione, 13
# 18          Rivolta d'Adda, Stefano Renzi, 5
# 19                     Agnadello, Marconi, 6
# 20              Capergnanica, XI febbraio, 7
# 21  Pescarolo ed Uniti, Giuseppe Mazzini, 73
# 22                       Vescovato, Roma, 44
# 23                       Ostiano, Mazzini, 1
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39                                       NaN
# 40                                       NaN
# 41                                       NaN
# 42                                       NaN
# 43                                       NaN
# 44                                       NaN
# 45                                       NaN
# 46                                       NaN
# 47                                       NaN
# 48                                       NaN
# 49                                       NaN

# %%
fur1_copy.to_csv("../Dati/turni_f/multi_veich_LS1.csv", sep=";", index=False)
fur2_copy.to_csv("../Dati/turni_f/multi_veich_LS2.csv", sep=";", index=False)

# %%
fur2_copy = pd.DataFrame({})
fur2_copy['col'] = pd.Series([np.nan]*50)
fur2_copy = fur2_copy.join(fur2)
fur2_copy[["martedi", "mercoledi", "giovedi"]]

# %%
fur1_copy = pd.DataFrame({})
fur1_copy['col'] = pd.Series([0]*50)
fur1_copy = fur1_copy.join(fur1)
temp_list = pd.Series(["ciao"])
padding=pd.Series([np.nan]*(50-len(temp_list)))
temp_list = pd.concat([temp_list, padding], ignore_index=True)
fur1_copy[best_day] = fur1_copy[best_day].replace(list(fur1_copy[best_day]), temp_list)
