# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import folium
from collections import Counter

df = pd.read_csv("../Dati/request_cr.csv", delimiter=",", encoding = "ISO-8859-1")
to_ = list(df['biblioteca_destinazione'])
from_ = list(df['biblioteca_partenza'])
data = np.column_stack((from_, to_)).tolist()
occ = [[x, data.count(x)] for x in data]

# %%
occ
# Out:
# [[["RIVOLTA D'ADDA", 'BONEMERSE'], 53],
#  [["RIVOLTA D'ADDA", 'ROMANENGO'], 59],
#  [["RIVOLTA D'ADDA", 'Agnadello'], 108],
#  [["RIVOLTA D'ADDA", "SPINO D'ADDA"], 114],
#  [["RIVOLTA D'ADDA", "SPINO D'ADDA"], 114],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['GADESCO PIEVE DELMONA', 'GADESCO PIEVE DELMONA'], 110],
#  [['PALAZZO PIGNANO', "SPINO D'ADDA"], 35],
#  [['PALAZZO PIGNANO', "RIVOLTA D'ADDA"], 18],
#  [['PALAZZO PIGNANO', 'PIADENA DRIZZONA'], 25],
#  [['OFFANENGO', 'VESCOVATO'], 84],
#  [['OFFANENGO', 'VESCOVATO'], 84],
#  [['BRESCIA', 'RICENGO'], 801],
#  [['OFFANENGO', 'MONTE CREMASCO'], 300],
#  [['MONTODINE', 'OFFANENGO'], 19],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['BRESCIA', 'PESCAROLO ED UNITI'], 713],
#  [['VESCOVATO', 'ISOLA DOVARESE'], 16],
#  [['VESCOVATO', 'MONTE CREMASCO'], 36],
#  [['GADESCO PIEVE DELMONA', 'MONTE CREMASCO'], 54],
#  [['GADESCO PIEVE DELMONA', 'PIADENA DRIZZONA'], 29],
#  [['CASALMAGGIORE', 'PIANENGO'], 65],
#  [['CASALMAGGIORE', 'MONTODINE'], 54],
#  [['CASALMAGGIORE', 'MONTE CREMASCO'], 86],
#  [['CASALMAGGIORE', 'UFF. BIB. CREMONA'], 4],
#  [['CASALMAGGIORE', 'BONEMERSE'], 36],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['CASALMAGGIORE', 'OFFANENGO'], 266],
#  [['ROMANENGO', 'UFF. BIB. CREMONA'], 2],
#  [['ROMANENGO', 'CAPRALBA'], 9],
#  [['PIZZIGHETTONE', 'PIZZIGHETTONE'], 80],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['OFFANENGO', 'SONCINO'], 300],
#  [['SONCINO', 'BRESCIA'], 325],
#  [['BRESCIA', 'MONTODINE'], 532],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['MARTIGNANA DI PO', 'MONTODINE'], 18],
#  [['MARTIGNANA DI PO', 'VESCOVATO'], 9],
#  [['GUSSOLA', 'BRESCIA'], 80],
#  [['OFFANENGO', 'CASALMAGGIORE'], 70],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['GUSSOLA', 'SAN GIOVANNI IN CROCE'], 18],
#  [['SOLAROLO RAINERIO', 'PANDINO'], 76],
#  [['TRESCORE CREMASCO', 'TRESCORE CREMASCO'], 32],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['CASTELLEONE', 'RICENGO'], 117],
#  [['CASTELLEONE', 'Agnadello'], 119],
#  [['CASTELLEONE', 'CASALMAGGIORE'], 99],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['CASTELLEONE', 'Agnadello'], 119],
#  [['CASTELLEONE', "SPINO D'ADDA"], 124],
#  [['CASTELLEONE', 'MONTODINE'], 120],
#  [['CASTELLEONE', 'CASTELLEONE'], 298],
#  [['PIANENGO', 'DOVERA'], 16],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['VESCOVATO', 'PANDINO'], 84],
#  [['BRESCIA', 'RICENGO'], 801],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'RICENGO'], 801],
#  [['BRESCIA', 'RICENGO'], 801],
#  [['RICENGO', 'TRESCORE CREMASCO'], 12],
#  [['TRESCORE CREMASCO', 'CASALMAGGIORE'], 6],
#  [['OFFANENGO', 'SONCINO'], 300],
#  [['PALAZZO PIGNANO', 'SORESINA'], 50],
#  [['PALAZZO PIGNANO', 'OFFANENGO'], 138],
#  [['SOLAROLO RAINERIO', "RIVOLTA D'ADDA"], 28],
#  [['CASTELLEONE', 'PIADENA DRIZZONA'], 120],
#  [["RIVOLTA D'ADDA", "RIVOLTA D'ADDA"], 153],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['CASTELLEONE', "RIVOLTA D'ADDA"], 145],
#  [['SOSPIRO', 'ROMANENGO'], 3],
#  [['BRESCIA', 'PIADENA DRIZZONA'], 963],
#  [['CASTELLEONE', 'PIANENGO'], 127],
#  [['VESCOVATO', 'SONCINO'], 81],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['CASTELLEONE', 'CASTELLEONE'], 298],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'UFF. BIB. CREMONA'], 31],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'MARTIGNANA DI PO'], 133],
#  [['OFFANENGO', 'RIPALTA CREMASCA'], 118],
#  [['OFFANENGO', 'SONCINO'], 300],
#  [['OFFANENGO', 'RIPALTA CREMASCA'], 118],
#  [['OFFANENGO', 'CASALMAGGIORE'], 70],
#  [['SAN GIOVANNI IN CROCE', 'OFFANENGO'], 150],
#  [['SONCINO', 'SORESINA'], 73],
#  [['BRESCIA', 'MONTE CREMASCO'], 964],
#  [['BRESCIA', 'CASALETTO VAPRIO'], 27],
#  [['SAN GIOVANNI IN CROCE', 'CASALMAGGIORE'], 16],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['OFFANENGO', 'BRESCIA'], 891],
#  [['BRESCIA', 'TRESCORE CREMASCO'], 698],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['BRESCIA', 'RICENGO'], 801],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['PESCAROLO ED UNITI', "RIVOLTA D'ADDA"], 23],
#  [['PESCAROLO ED UNITI', 'PIZZIGHETTONE'], 16],
#  [['PESCAROLO ED UNITI', 'BRESCIA'], 170],
#  [['PESCAROLO ED UNITI', 'TRESCORE CREMASCO'], 15],
#  [["SPINO D'ADDA", 'PIANENGO'], 48],
#  [['SAN GIOVANNI IN CROCE', "SPINO D'ADDA"], 36],
#  [['OFFANENGO', 'PESCAROLO ED UNITI'], 120],
#  [['OFFANENGO', 'VESCOVATO'], 84],
#  [['BRESCIA', 'PIZZIGHETTONE'], 389],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['GRONTARDO', 'SONCINO'], 35],
#  [['CASALMAGGIORE', 'OFFANENGO'], 266],
#  [['CASALMAGGIORE', 'OFFANENGO'], 266],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['VESCOVATO', 'BONEMERSE'], 21],
#  [['CASALMAGGIORE', 'OFFANENGO'], 266],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['BRESCIA', 'RICENGO'], 801],
#  [['OFFANENGO', 'VESCOVATO'], 84],
#  [['DOVERA', 'GRUMELLO CREMONESE'], 2],
#  [['DOVERA', 'RIPALTA CREMASCA'], 27],
#  [['DOVERA', "CINGIA DE' BOTTI"], 10],
#  [['DOVERA', 'BRESCIA'], 186],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['CASTELLEONE', 'PIANENGO'], 127],
#  [['CASTELLEONE', 'MADIGNANO'], 232],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['CASTELLEONE', 'TRESCORE CREMASCO'], 86],
#  [['GUSSOLA', 'MADIGNANO'], 15],
#  [['CASTELVERDE', 'BRESCIA'], 125],
#  [['CASTELVERDE', 'PANDINO'], 11],
#  [["RIVOLTA D'ADDA", "RIVOLTA D'ADDA"], 153],
#  [['MADIGNANO', 'BRESCIA'], 283],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['CASTELLEONE', 'PANDINO'], 312],
#  [["RIVOLTA D'ADDA", "RIVOLTA D'ADDA"], 153],
#  [['PERSICO DOSIMO', 'BAGNOLO CREMASCO'], 11],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['RICENGO', 'PIANENGO'], 9],
#  [['VAIANO CREMASCO', 'BRESCIA'], 105],
#  [['VAIANO CREMASCO', "RIVOLTA D'ADDA"], 7],
#  [['VAIANO CREMASCO', 'SONCINO'], 25],
#  [['VAIANO CREMASCO', 'OFFANENGO'], 48],
#  [['GADESCO PIEVE DELMONA', "SPINO D'ADDA"], 37],
#  [['BAGNOLO CREMASCO', 'DOVERA'], 36],
#  [['BAGNOLO CREMASCO', "RIVOLTA D'ADDA"], 198],
#  [['BAGNOLO CREMASCO', "RIVOLTA D'ADDA"], 198],
#  [['VAIANO CREMASCO', 'VAIANO CREMASCO'], 28],
#  [['BAGNOLO CREMASCO', 'BRESCIA'], 574],
#  [['GADESCO PIEVE DELMONA', 'SORESINA'], 78],
#  [['BRESCIA', 'VESCOVATO'], 470],
#  [['BAGNOLO CREMASCO', 'OFFANENGO'], 290],
#  [['BAGNOLO CREMASCO', 'OFFANENGO'], 290],
#  [['BAGNOLO CREMASCO', 'BAGNOLO CREMASCO'], 162],
#  [['BAGNOLO CREMASCO', 'BAGNOLO CREMASCO'], 162],
#  [['BAGNOLO CREMASCO', 'BAGNOLO CREMASCO'], 162],
#  [['BAGNOLO CREMASCO', 'BAGNOLO CREMASCO'], 162],
#  [["SPINO D'ADDA", 'OFFANENGO'], 195],
#  [['SORESINA', 'BRESCIA'], 310],
#  [['SORESINA', 'BRESCIA'], 310],
#  [['BAGNOLO CREMASCO', 'SONCINO'], 141],
#  [['BAGNOLO CREMASCO', 'BAGNOLO CREMASCO'], 162],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['BAGNOLO CREMASCO', "RIVOLTA D'ADDA"], 198],
#  [['PESCAROLO ED UNITI', 'SORESINA'], 62],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['CASTELLEONE', 'SONCINO'], 289],
#  [['GUSSOLA', 'PERSICO DOSIMO'], 12],
#  [['OFFANENGO', 'GUSSOLA'], 41],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['CASTELLEONE', 'RICENGO'], 117],
#  [['CASTELLEONE', 'RICENGO'], 117],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['PIANENGO', 'BONEMERSE'], 11],
#  [['PIANENGO', 'PANDINO'], 55],
#  [['PIANENGO', 'MADIGNANO'], 35],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['BRESCIA', 'SAN GIOVANNI IN CROCE'], 741],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [["CINGIA DE' BOTTI", "SPINO D'ADDA"], 13],
#  [['SOLAROLO RAINERIO', 'SONCINO'], 88],
#  [["CINGIA DE' BOTTI", 'BRESCIA'], 122],
#  [['PESCAROLO ED UNITI', 'PIZZIGHETTONE'], 16],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['PALAZZO PIGNANO', 'MADIGNANO'], 48],
#  [['PALAZZO PIGNANO', 'PERSICO DOSIMO'], 24],
#  [['VESCOVATO', 'VESCOVATO'], 34],
#  [['VESCOVATO', 'FIESCO'], 4],
#  [['VESCOVATO', 'SONCINO'], 81],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['SAN GIOVANNI IN CROCE', 'GUSSOLA'], 13],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['CASTELLEONE', 'SERGNANO'], 87],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [["SPINO D'ADDA", 'VESCOVATO'], 24],
#  [['ISOLA DOVARESE', 'BRESCIA'], 75],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['PANDINO', 'CREMA'], 364],
#  [['PANDINO', 'SONCINO'], 51],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['MONTE CREMASCO', 'SAN GIOVANNI IN CROCE'], 7],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [["CINGIA DE' BOTTI", 'CREMA'], 147],
#  [['CASALMAGGIORE', 'Agnadello'], 57],
#  [['CASALMAGGIORE', 'PIZZIGHETTONE'], 41],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CASALMAGGIORE', 'RICENGO'], 58],
#  [['CASALMAGGIORE', 'SAN GIOVANNI IN CROCE'], 145],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['CASALMAGGIORE', 'BONEMERSE'], 36],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['CASALMAGGIORE', 'SAN GIOVANNI IN CROCE'], 145],
#  [['CASALMAGGIORE', 'MADIGNANO'], 104],
#  [['CASALMAGGIORE', 'MADIGNANO'], 104],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CREMA', 'OFFANENGO'], 591],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['CREMA', 'PALAZZO PIGNANO'], 102],
#  [['RIPALTA CREMASCA', 'BRESCIA'], 130],
#  [['CREMA', "RIVOLTA D'ADDA"], 249],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['VAILATE', 'OFFANENGO'], 58],
#  [['VAILATE', 'BRESCIA'], 187],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['CASTELLEONE', "RIVOLTA D'ADDA"], 145],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['UFF. BIB. CREMONA', 'UFF. BIB. CREMONA'], 2],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [["CINGIA DE' BOTTI", 'CREMA'], 147],
#  [["CINGIA DE' BOTTI", 'SORESINA'], 27],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['BRESCIA', 'SAN GIOVANNI IN CROCE'], 741],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['CREMA', "RIVOLTA D'ADDA"], 249],
#  [['BRESCIA', 'PIZZIGHETTONE'], 389],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['CREMA', 'RIPALTA CREMASCA'], 184],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['CASTELVERDE', 'BRESCIA'], 125],
#  [['MARTIGNANA DI PO', 'BRESCIA'], 179],
#  [['MARTIGNANA DI PO', 'SORESINA'], 25],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['CASTELLEONE', 'VESCOVATO'], 57],
#  [['UNIONE MUNICIPIA', 'MADIGNANO'], 30],
#  [['UNIONE MUNICIPIA', 'BRESCIA'], 129],
#  [['UNIONE MUNICIPIA', 'SONCINO'], 27],
#  [['GUSSOLA', 'CASALMAGGIORE'], 10],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['TRIGOLO', 'MADIGNANO'], 16],
#  [['SAN GIOVANNI IN CROCE', "CINGIA DE' BOTTI"], 20],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['TRESCORE CREMASCO', 'BRESCIA'], 179],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['OSTIANO', 'BRESCIA'], 73],
#  [['CASALBUTTANO', 'CREMA'], 49],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['TRESCORE CREMASCO', 'OFFANENGO'], 67],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['SERGNANO', 'BRESCIA'], 364],
#  [['SERGNANO', 'SONCINO'], 166],
#  [['SERGNANO', 'OFFANENGO'], 314],
#  [['SERGNANO', "RIVOLTA D'ADDA"], 70],
#  [['SERGNANO', "SPINO D'ADDA"], 63],
#  [['SERGNANO', 'CREMA'], 926],
#  [['PALAZZO PIGNANO', 'TRESCORE CREMASCO'], 23],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['Agnadello', 'CASALMAGGIORE'], 9],
#  [['Agnadello', 'CREMA'], 217],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['SOLAROLO RAINERIO', 'CREMA'], 456],
#  [['SONCINO', 'BRESCIA'], 325],
#  [['SONCINO', 'CREMA'], 362],
#  [['SONCINO', 'CREMA'], 362],
#  [['VESCOVATO', 'VESCOVATO'], 34],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['SERGNANO', 'CASALMAGGIORE'], 61],
#  [['VESCOVATO', 'CREMA'], 319],
#  [['VESCOVATO', 'CREMA'], 319],
#  [['VESCOVATO', 'CREMA'], 319],
#  [['VESCOVATO', "SPINO D'ADDA"], 35],
#  [['UNIONE MUNICIPIA', 'UNIONE MUNICIPIA'], 22],
#  [['PERSICO DOSIMO', 'BRESCIA'], 99],
#  [['GRUMELLO CREMONESE', 'GRUMELLO CREMONESE'], 11],
#  [['PERSICO DOSIMO', 'CREMA'], 136],
#  [['BRESCIA', 'ISOLA DOVARESE'], 598],
#  [['CASTELLEONE', 'SORESINA'], 301],
#  [['PESCAROLO ED UNITI', 'CREMA'], 348],
#  [["RIVOLTA D'ADDA", 'SONCINO'], 430],
#  [["RIVOLTA D'ADDA", 'CASALMAGGIORE'], 102],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['GUSSOLA', 'OFFANENGO'], 62],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['OFFANENGO', 'GUSSOLA'], 41],
#  [['ISOLA DOVARESE', 'SORESINA'], 27],
#  [['ISOLA DOVARESE', 'RIVAROLO DEL RE'], 1],
#  [['PALAZZO PIGNANO', 'CREMA'], 316],
#  [["RIVOLTA D'ADDA", "SPINO D'ADDA"], 114],
#  [["RIVOLTA D'ADDA", 'VESCOVATO'], 52],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [['SERGNANO', 'CREMA'], 926],
#  [['SOLAROLO RAINERIO', 'SOSPIRO'], 37],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [["CINGIA DE' BOTTI", "CINGIA DE' BOTTI"], 1436],
#  [['SERGNANO', 'SONCINO'], 166],
#  [['SERGNANO', 'CREMA'], 926],
#  [['PALAZZO PIGNANO', 'PESCAROLO ED UNITI'], 27],
#  [['PALAZZO PIGNANO', 'CASALMAGGIORE'], 19],
#  [["SPINO D'ADDA", 'PALAZZO PIGNANO'], 22],
#  [['SERGNANO', 'PESCAROLO ED UNITI'], 85],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CASALMAGGIORE', 'RIVAROLO DEL RE'], 11],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['VESCOVATO', 'PIANENGO'], 26],
#  [['VESCOVATO', 'SOSPIRO'], 41],
#  [['VESCOVATO', "SPINO D'ADDA"], 35],
#  [['CASALMAGGIORE', 'SONCINO'], 219],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['VAILATE', 'BRESCIA'], 187],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'SAN GIOVANNI IN CROCE'], 741],
#  [['BRESCIA', 'CREMONA. LA PICCOLA BIBLIOTECA'], 187],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['Agnadello', 'Agnadello'], 327],
#  [['Agnadello', 'SAN GIOVANNI IN CROCE'], 19],
#  [['Agnadello', 'PESCAROLO ED UNITI'], 11],
#  [['Agnadello', 'OFFANENGO'], 96],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['CASTELLEONE', 'RIPALTA CREMASCA'], 146],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [["SPINO D'ADDA", 'RIVAROLO DEL RE'], 4],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [['CASTELLEONE', 'ISOLA DOVARESE'], 73],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['CASTELLEONE', 'PIANENGO'], 127],
#  [["RIVOLTA D'ADDA", 'PALAZZO PIGNANO'], 44],
#  [["RIVOLTA D'ADDA", 'MADIGNANO'], 204],
#  [["RIVOLTA D'ADDA", 'ANNICCO'], 8],
#  [['CASTELLEONE', "SPINO D'ADDA"], 124],
#  [['CASTELLEONE', 'Agnadello'], 119],
#  [['CASTELLEONE', 'CASALMAGGIORE'], 99],
#  [['CASTELLEONE', 'CASALMAGGIORE'], 99],
#  [['GRONTARDO', 'GADESCO PIEVE DELMONA'], 3],
#  [['GRONTARDO', 'CASALMAGGIORE'], 8],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [["SPINO D'ADDA", 'CREMA'], 524],
#  [['GRONTARDO', "SPINO D'ADDA"], 14],
#  [['SERGNANO', 'RIPALTA CREMASCA'], 92],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['SERGNANO', "SPINO D'ADDA"], 63],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'CASALMAGGIORE'], 102],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [["RIVOLTA D'ADDA", 'RIPALTA CREMASCA'], 93],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [["RIVOLTA D'ADDA", "SPINO D'ADDA"], 114],
#  [['PALAZZO PIGNANO', 'PIANENGO'], 33],
#  [['SERGNANO', 'BRESCIA'], 364],
#  [['BRESCIA', 'SOLAROLO RAINERIO'], 614],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [["SPINO D'ADDA", 'OFFANENGO'], 195],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['CASTELLEONE', 'UFF. BIB. CREMONA'], 2],
#  [['PALAZZO PIGNANO', "SPINO D'ADDA"], 35],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['SAN GIOVANNI IN CROCE', 'CREMA'], 404],
#  [['SAN GIOVANNI IN CROCE', 'BRESCIA'], 242],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['BRESCIA', 'MONTODINE'], 532],
#  [['CREMONA - CDA', 'SONCINO'], 19],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['PANDINO', 'CREMA'], 364],
#  [['PANDINO', 'GRONTARDO'], 1],
#  [['BRESCIA', 'MONTODINE'], 532],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['GADESCO PIEVE DELMONA', 'BRESCIA'], 400],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['CREMA', 'OFFANENGO'], 591],
#  [['PALAZZO PIGNANO', 'SORESINA'], 50],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'UFF. BIB. CREMONA'], 31],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['OFFANENGO', 'SONCINO'], 300],
#  [['PALAZZO PIGNANO', 'CREMA'], 316],
#  [['MARTIGNANA DI PO', 'RIPALTA CREMASCA'], 25],
#  [['MARTIGNANA DI PO', 'SAN GIOVANNI IN CROCE'], 22],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['BRESCIA', 'GADESCO PIEVE DELMONA'], 130],
#  [['CASALMAGGIORE', 'UFF. BIB. CREMONA'], 4],
#  [['BRESCIA', 'TRESCORE CREMASCO'], 698],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CASALMAGGIORE', "CINGIA DE' BOTTI"], 43],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CASALMAGGIORE', 'Agnadello'], 57],
#  [['CASALMAGGIORE', "SPINO D'ADDA"], 71],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['CREMA', 'SONCINO'], 370],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['OFFANENGO', 'CREMONA - CDA'], 118],
#  [['BRESCIA', 'PIZZIGHETTONE'], 389],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['DOVERA', 'CREMA'], 247],
#  [['CREMA', 'CREMA'], 1417],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', "CINGIA DE' BOTTI"], 405],
#  [['BAGNOLO CREMASCO', 'TRIGOLO'], 20],
#  [['BAGNOLO CREMASCO', 'PIANENGO'], 78],
#  [['BAGNOLO CREMASCO', 'BRESCIA'], 574],
#  [['BAGNOLO CREMASCO', 'TRIGOLO'], 20],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['GUSSOLA', "SPINO D'ADDA"], 9],
#  [['GUSSOLA', 'SOLAROLO RAINERIO'], 7],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CREMA', 'CREMONA - CDA'], 187],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['RICENGO', 'OFFANENGO'], 48],
#  [['CREMA', 'BONEMERSE'], 46],
#  [['BRESCIA', 'RICENGO'], 801],
#  [["RIVOLTA D'ADDA", 'UFF. BIB. CREMONA'], 5],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['CREMA', "SPINO D'ADDA"], 147],
#  [['OFFANENGO', 'CAPRALBA'], 89],
#  [['CREMA', 'CASALMAGGIORE'], 102],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['RICENGO', 'RIPALTA CREMASCA'], 23],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['SERGNANO', 'GUSSOLA'], 23],
#  [['RIPALTA CREMASCA', 'OFFANENGO'], 32],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['GUSSOLA', 'CAPRALBA'], 9],
#  [['SONCINO', 'SORESINA'], 73],
#  [['BRESCIA', 'MARTIGNANA DI PO'], 133],
#  [['SONCINO', 'PIANENGO'], 28],
#  [['SONCINO', "CINGIA DE' BOTTI"], 16],
#  [['CASTELVERDE', 'CASALMAGGIORE'], 13],
#  [['CASTELVERDE', 'CREMA'], 117],
#  [['SERGNANO', 'CAPRALBA'], 63],
#  [['CREMA', 'PANDINO'], 285],
#  [['RICENGO', 'GUSSOLA'], 6],
#  [['SORESINA', 'GUSSOLA'], 12],
#  [['SORESINA', "RIVOLTA D'ADDA"], 35],
#  [['SORESINA', 'CREMA'], 334],
#  [['SORESINA', 'OFFANENGO'], 111],
#  [['SORESINA', 'CAPERGNANICA'], 10],
#  [['OFFANENGO', 'CASALMAGGIORE'], 70],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['SOLAROLO RAINERIO', "CINGIA DE' BOTTI"], 43],
#  [['VESCOVATO', 'CREMA'], 319],
#  [['BRESCIA', 'PESCAROLO ED UNITI'], 713],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['Agnadello', 'SONCINO'], 32],
#  [['BRESCIA', 'CAPRALBA'], 676],
#  [['VESCOVATO', 'PERSICO DOSIMO'], 25],
#  [['CASALMAGGIORE', 'SOSPIRO'], 100],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [['CASALMAGGIORE', 'CASALMAGGIORE'], 395],
#  [['CASALMAGGIORE', "SPINO D'ADDA"], 71],
#  [['CASALMAGGIORE', 'PIZZIGHETTONE'], 41],
#  [['VAIANO CREMASCO', 'BRESCIA'], 105],
#  [['VAIANO CREMASCO', 'SONCINO'], 25],
#  [['VAIANO CREMASCO', 'OFFANENGO'], 48],
#  [['CREMA', 'MADIGNANO'], 261],
#  [['ISOLA DOVARESE', 'SOLAROLO RAINERIO'], 6],
#  [["CINGIA DE' BOTTI", 'PERSICO DOSIMO'], 19],
#  [['SOLAROLO RAINERIO', 'CREMA'], 456],
#  [['BRESCIA', 'PIADENA DRIZZONA'], 963],
#  [['MADIGNANO', 'CREMA'], 305],
#  [['MADIGNANO', 'CREMA'], 305],
#  [['CASALMAGGIORE', "SPINO D'ADDA"], 71],
#  [['PIANENGO', "SPINO D'ADDA"], 14],
#  [['VESCOVATO', "SPINO D'ADDA"], 35],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CAPRALBA', 'SORESINA'], 57],
#  [['CASALBUTTANO', 'MARTIGNANA DI PO'], 1],
#  [['CASALBUTTANO', "RIVOLTA D'ADDA"], 6],
#  [['CAPRALBA', 'BONEMERSE'], 9],
#  [['CAPRALBA', 'SOLAROLO RAINERIO'], 24],
#  [['CAPRALBA', 'RICENGO'], 30],
#  [['CAPRALBA', 'PIZZIGHETTONE'], 14],
#  [['CAPRALBA', 'CASALMAGGIORE'], 14],
#  [['CAPRALBA', 'CREMA'], 358],
#  [['BRESCIA', 'BAGNOLO CREMASCO'], 760],
#  [['MADIGNANO', 'MADIGNANO'], 58],
#  [['MADIGNANO', 'MADIGNANO'], 58],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [["RIVOLTA D'ADDA", "RIVOLTA D'ADDA"], 153],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['CREMA', 'SONCINO'], 370],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['CASALMAGGIORE', 'PIANENGO'], 65],
#  [['CASALMAGGIORE', 'MONTE CREMASCO'], 86],
#  [['OFFANENGO', 'PANDINO'], 349],
#  [['CASALMAGGIORE', "SPINO D'ADDA"], 71],
#  [['BRESCIA', 'PANDINO'], 1441],
#  [['PESCAROLO ED UNITI', 'CREMA'], 348],
#  [['VESCOVATO', 'BRESCIA'], 255],
#  [['VAILATE', 'VAILATE'], 48],
#  [['OFFANENGO', 'MADIGNANO'], 230],
#  [['BAGNOLO CREMASCO', 'MONTE CREMASCO'], 109],
#  [['BAGNOLO CREMASCO', 'MONTE CREMASCO'], 109],
#  [['BAGNOLO CREMASCO', 'MONTE CREMASCO'], 109],
#  [['BAGNOLO CREMASCO', 'MONTE CREMASCO'], 109],
#  [['BAGNOLO CREMASCO', 'SORESINA'], 152],
#  [['SONCINO', 'PANDINO'], 63],
#  [['SONCINO', 'BRESCIA'], 325],
#  [['BAGNOLO CREMASCO', 'MONTE CREMASCO'], 109],
#  [['BAGNOLO CREMASCO', "RIVOLTA D'ADDA"], 198],
#  [['SONCINO', "SPINO D'ADDA"], 26],
#  [['SONCINO', 'PIANENGO'], 28],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['MADIGNANO', 'PERSICO DOSIMO'], 14],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['SAN GIOVANNI IN CROCE', 'CREMA'], 404],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['RICENGO', 'SOLAROLO RAINERIO'], 10],
#  [['CREMA', 'RICENGO'], 120],
#  [['CREMA', 'RICENGO'], 120],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['CASTELLEONE', 'CASALBUTTANO'], 83],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['BRESCIA', 'PIANENGO'], 694],
#  [['BRESCIA', 'MONTE CREMASCO'], 964],
#  [['SESTO ED UNITI', 'BRESCIA'], 13],
#  [['SESTO ED UNITI', 'ANNICCO'], 1],
#  [['SESTO ED UNITI', 'CREMONA. LA PICCOLA BIBLIOTECA'], 1],
#  [['OFFANENGO', 'MONTE CREMASCO'], 300],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['OFFANENGO', "SPINO D'ADDA"], 116],
#  [['CASTELLEONE', 'CASALMAGGIORE'], 99],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['TRIGOLO', 'PIANENGO'], 6],
#  [['CAPERGNANICA', 'FIESCO'], 9],
#  [['PESCAROLO ED UNITI', 'CREMA'], 348],
#  [['RIPALTA CREMASCA', 'CAPRALBA'], 4],
#  [['CASTELLEONE', 'Agnadello'], 119],
#  [['CASTELLEONE', 'RICENGO'], 117],
#  [['CASTELLEONE', 'OFFANENGO'], 460],
#  [['SOLAROLO RAINERIO', "SPINO D'ADDA"], 29],
#  [['RIPALTA CREMASCA', 'SORESINA'], 9],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['VAIANO CREMASCO', 'BONEMERSE'], 6],
#  [['VAIANO CREMASCO', "RIVOLTA D'ADDA"], 7],
#  [['BRESCIA', 'PIZZIGHETTONE'], 389],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [["RIVOLTA D'ADDA", "SPINO D'ADDA"], 114],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'RICENGO'], 91],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [["RIVOLTA D'ADDA", 'MADIGNANO'], 204],
#  [["RIVOLTA D'ADDA", 'MADIGNANO'], 204],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", "CINGIA DE' BOTTI"], 43],
#  [["RIVOLTA D'ADDA", 'PIANENGO'], 84],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['SONCINO', 'CASALMAGGIORE'], 22],
#  [['SONCINO', 'CREMA'], 362],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['PIANENGO', 'MONTODINE'], 13],
#  [['RICENGO', 'BRESCIA'], 126],
#  [['CASTELLEONE', 'CASALMAGGIORE'], 99],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'PIZZIGHETTONE'], 49],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [['PIZZIGHETTONE', 'BRESCIA'], 420],
#  [['PIZZIGHETTONE', 'GUSSOLA'], 6],
#  [['PIZZIGHETTONE', 'BRESCIA'], 420],
#  [['PIZZIGHETTONE', 'SORESINA'], 49],
#  [['OFFANENGO', 'BRESCIA'], 891],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['PIZZIGHETTONE', 'CREMA'], 386],
#  [['PIZZIGHETTONE', 'BONEMERSE'], 21],
#  [['PIZZIGHETTONE', 'FIESCO'], 9],
#  [['PIZZIGHETTONE', 'CASALMAGGIORE'], 13],
#  [['BRESCIA', 'VESCOVATO'], 470],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'PANDINO'], 1441],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['BRESCIA', 'PIZZIGHETTONE'], 389],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['CAPRALBA', 'VESCOVATO'], 24],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['OFFANENGO', 'CASALMAGGIORE'], 70],
#  [['BRESCIA', 'BONEMERSE'], 404],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['Agnadello', 'SOSPIRO'], 24],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['Agnadello', 'DOVERA'], 9],
#  [['SONCINO', 'Agnadello'], 44],
#  [['SOSPIRO', 'BRESCIA'], 78],
#  [['SONCINO', "SPINO D'ADDA"], 26],
#  [['SONCINO', 'SOSPIRO'], 34],
#  [['CASALMAGGIORE', 'SOSPIRO'], 100],
#  [['CASALMAGGIORE', 'SAN GIOVANNI IN CROCE'], 145],
#  [['CASALMAGGIORE', 'Agnadello'], 57],
#  [['CASALMAGGIORE', 'SOSPIRO'], 100],
#  [['CASALMAGGIORE', 'OFFANENGO'], 266],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CASALMAGGIORE', 'SORESINA'], 181],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['BRESCIA', 'CREMA'], 20176],
#  [["SPINO D'ADDA", 'PERSICO DOSIMO'], 34],
#  [['BRESCIA', 'CASALETTO VAPRIO'], 27],
#  [['MADIGNANO', 'BONEMERSE'], 13],
#  [['MADIGNANO', 'VESCOVATO'], 13],
#  [['MADIGNANO', 'MONTE CREMASCO'], 53],
#  [['SERGNANO', 'CASALMAGGIORE'], 61],
#  [['SERGNANO', 'SORESINA'], 138],
#  [['SERGNANO', 'CREMA'], 926],
#  [['SERGNANO', 'CREMA'], 926],
#  [['SERGNANO', 'Agnadello'], 87],
#  [["SPINO D'ADDA", "SPINO D'ADDA"], 48],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['SAN GIOVANNI IN CROCE', "SPINO D'ADDA"], 36],
#  [['SAN GIOVANNI IN CROCE', 'MONTE CREMASCO'], 47],
#  [["SPINO D'ADDA", "SPINO D'ADDA"], 48],
#  [["SPINO D'ADDA", "SPINO D'ADDA"], 48],
#  [['OFFANENGO', 'CASALMAGGIORE'], 70],
#  [["SPINO D'ADDA", 'RIPALTA CREMASCA'], 57],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['OFFANENGO', 'BRESCIA'], 891],
#  [['OFFANENGO', "SPINO D'ADDA"], 116],
#  [['OFFANENGO', 'BRESCIA'], 891],
#  [['GADESCO PIEVE DELMONA', 'CAMISANO'], 5],
#  [['GADESCO PIEVE DELMONA', 'CREMA'], 453],
#  [['GADESCO PIEVE DELMONA', 'UNIONE MUNICIPIA'], 19],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['VESCOVATO', "SPINO D'ADDA"], 35],
#  [['MONTODINE', 'BRESCIA'], 59],
#  [['MONTODINE', 'SONCINO'], 10],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['OFFANENGO', 'CASALMAGGIORE'], 70],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['OFFANENGO', 'SORESINA'], 228],
#  [['PIADENA DRIZZONA', 'PIADENA DRIZZONA'], 204],
#  [['CREMONA - CDA', 'CAPRALBA'], 6],
#  [['OFFANENGO', 'OFFANENGO'], 246],
#  [['CREMONA - CDA', 'BRESCIA'], 155],
#  [['CREMONA - CDA', 'CAPRALBA'], 6],
#  [['CREMONA - CDA', 'CAPRALBA'], 6],
#  [['CREMONA - CDA', 'MONTE CREMASCO'], 8],
#  [['CREMONA - CDA', 'MONTE CREMASCO'], 8],
#  [['BRESCIA', 'MARTIGNANA DI PO'], 133],
#  [['BRESCIA', 'VESCOVATO'], 470],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['PIADENA DRIZZONA', 'PIADENA DRIZZONA'], 204],
#  [['CREMONA - CDA', 'BRESCIA'], 155],
#  [['SAN GIOVANNI IN CROCE', 'RIPALTA CREMASCA'], 38],
#  [['GADESCO PIEVE DELMONA', 'MONTE CREMASCO'], 54],
#  [['GADESCO PIEVE DELMONA', 'DOVERA'], 18],
#  [['GADESCO PIEVE DELMONA', 'CREMA'], 453],
#  [['GADESCO PIEVE DELMONA', 'PIADENA DRIZZONA'], 29],
#  [['CASALMAGGIORE', 'BONEMERSE'], 36],
#  [['CASALMAGGIORE', 'RIPALTA CREMASCA'], 65],
#  [['CREMONA - CDA', 'CAPRALBA'], 6],
#  [['SERGNANO', 'PIADENA DRIZZONA'], 80],
#  [['CASALMAGGIORE', 'MONTODINE'], 54],
#  [['CASALMAGGIORE', 'BRESCIA'], 1223],
#  [['CASALMAGGIORE', 'CREMONA - CDA'], 107],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'PIZZIGHETTONE'], 389],
#  [['GADESCO PIEVE DELMONA', 'BRESCIA'], 400],
#  [['OFFANENGO', 'PIADENA DRIZZONA'], 92],
#  [['BRESCIA', 'DOVERA'], 495],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['MARTIGNANA DI PO', 'SONCINO'], 31],
#  [['MARTIGNANA DI PO', 'CREMA'], 217],
#  [['MARTIGNANA DI PO', 'RIPALTA CREMASCA'], 25],
#  [['MARTIGNANA DI PO', 'PANDINO'], 32],
#  [['RICENGO', "SPINO D'ADDA"], 12],
#  [['PANDINO', 'RIPALTA CREMASCA'], 27],
#  [['PANDINO', 'BRESCIA'], 249],
#  [['PANDINO', 'RIPALTA CREMASCA'], 27],
#  [['BRESCIA', 'PESCAROLO ED UNITI'], 713],
#  [['BRESCIA', 'VESCOVATO'], 470],
#  [['BRESCIA', "SPINO D'ADDA"], 791],
#  [['PALAZZO PIGNANO', 'BRESCIA'], 106],
#  [['PALAZZO PIGNANO', 'RIPALTA CREMASCA'], 38],
#  [['PALAZZO PIGNANO', 'RIPALTA CREMASCA'], 38],
#  [['TRESCORE CREMASCO', 'SOSPIRO'], 24],
#  [['BRESCIA', 'SOSPIRO'], 1112],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['PANDINO', 'CASALMAGGIORE'], 14],
#  [['OSTIANO', "SPINO D'ADDA"], 7],
#  [['OSTIANO', 'PIADENA DRIZZONA'], 8],
#  [['OSTIANO', 'TRESCORE CREMASCO'], 6],
#  [['UFF. BIB. CREMONA', "SPINO D'ADDA"], 1],
#  [['UFF. BIB. CREMONA', 'CASALMAGGIORE'], 2],
#  [['UFF. BIB. CREMONA', 'BRESCIA'], 8],
#  [['UFF. BIB. CREMONA', 'CREMA'], 5],
#  [['SORESINA', 'BRESCIA'], 310],
#  [['BRESCIA', 'PANDINO'], 1441],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['SONCINO', 'CREMA'], 362],
#  [['SONCINO', 'RIPALTA CREMASCA'], 35],
#  [['ANNICCO', 'SAN GIOVANNI IN CROCE'], 2],
#  [['SOLAROLO RAINERIO', 'CAPRALBA'], 38],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['GUSSOLA', 'MONTE CREMASCO'], 16],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['CASTELLEONE', 'CASALBUTTANO'], 83],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['CASTELLEONE', 'BRESCIA'], 864],
#  [['BRESCIA', "CINGIA DE' BOTTI"], 405],
#  [['RICENGO', 'MONTE CREMASCO'], 24],
#  [['CASTELLEONE', 'CASALBUTTANO'], 83],
#  [['BRESCIA', 'PANDINO'], 1441],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['CASTELLEONE', "SPINO D'ADDA"], 124],
#  [['CASTELLEONE', 'SAN GIOVANNI IN CROCE'], 87],
#  [['PIADENA DRIZZONA', 'BRESCIA'], 573],
#  [['PIADENA DRIZZONA', 'BRESCIA'], 573],
#  [['PIADENA DRIZZONA', 'BRESCIA'], 573],
#  [['PIADENA DRIZZONA', 'SORESINA'], 110],
#  [['PIADENA DRIZZONA', "SPINO D'ADDA"], 48],
#  [['PIADENA DRIZZONA', 'CREMA'], 792],
#  [['PIADENA DRIZZONA', "RIVOLTA D'ADDA"], 61],
#  [['PIADENA DRIZZONA', 'BRESCIA'], 573],
#  [['PIADENA DRIZZONA', 'CREMA'], 792],
#  [['PIADENA DRIZZONA', 'CREMA'], 792],
#  [['PIADENA DRIZZONA', 'PESCAROLO ED UNITI'], 42],
#  [['PIADENA DRIZZONA', 'CREMA'], 792],
#  [['PIADENA DRIZZONA', 'Agnadello'], 37],
#  [['PIADENA DRIZZONA', 'CREMA'], 792],
#  [['PIADENA DRIZZONA', 'CASALMAGGIORE'], 46],
#  [['CASTELLEONE', 'SOSPIRO'], 164],
#  [['BRESCIA', 'SOSPIRO'], 1112],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['OFFANENGO', 'VESCOVATO'], 84],
#  [['RICENGO', 'MONTE CREMASCO'], 24],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [["RIVOLTA D'ADDA", 'CREMA'], 1965],
#  [['GRONTARDO', "RIVOLTA D'ADDA"], 15],
#  [['BRESCIA', 'SAN GIOVANNI IN CROCE'], 741],
#  [['BRESCIA', 'CREMA'], 20176],
#  [["RIVOLTA D'ADDA", 'BRESCIA'], 1641],
#  [['GRONTARDO', 'SORESINA'], 34],
#  [['PANDINO', 'CAMISANO'], 10],
#  [['PANDINO', 'CAMISANO'], 10],
#  [['BRESCIA', 'MONTE CREMASCO'], 964],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [["RIVOLTA D'ADDA", 'PIADENA DRIZZONA'], 116],
#  [["RIVOLTA D'ADDA", 'MONTE CREMASCO'], 110],
#  [['CASALMAGGIORE', 'SAN GIOVANNI IN CROCE'], 145],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['PALAZZO PIGNANO', 'CAMISANO'], 5],
#  [['PALAZZO PIGNANO', 'CAMISANO'], 5],
#  [['CASALMAGGIORE', 'CREMA'], 1316],
#  [['VESCOVATO', 'CAMISANO'], 8],
#  [['VESCOVATO', 'SONCINO'], 81],
#  [['VESCOVATO', 'CASALMAGGIORE'], 28],
#  [['SAN GIOVANNI IN CROCE', 'CAMISANO'], 5],
#  [['BRESCIA', 'SOSPIRO'], 1112],
#  [['CASTELLEONE', 'SONCINO'], 289],
#  [['ANNICCO', 'OFFANENGO'], 8],
#  [['ANNICCO', 'PIADENA DRIZZONA'], 2],
#  [['GRONTARDO', 'SONCINO'], 35],
#  [['ANNICCO', 'OFFANENGO'], 8],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['PALAZZO PIGNANO', 'CAPERGNANICA'], 12],
#  [['SOLAROLO RAINERIO', 'MONTODINE'], 35],
#  [['SOLAROLO RAINERIO', 'RIPALTA CREMASCA'], 33],
#  [['CASALMAGGIORE', 'VESCOVATO'], 53],
#  [['BRESCIA', 'CAMISANO'], 126],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['MADIGNANO', 'RIPALTA CREMASCA'], 31],
#  [['MADIGNANO', 'SORESINA'], 42],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['OFFANENGO', 'CREMA'], 1396],
#  [['VESCOVATO', 'BRESCIA'], 255],
#  [['VESCOVATO', 'CREMA'], 319],
#  [['OFFANENGO', 'SONCINO'], 300],
#  [['OFFANENGO', 'PANDINO'], 349],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['SAN GIOVANNI IN CROCE', 'SONCINO'], 75],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'SAN GIOVANNI IN CROCE'], 741],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['BRESCIA', 'Agnadello'], 1032],
#  [['BRESCIA', 'UNIONE MUNICIPIA'], 237],
#  [['SAN GIOVANNI IN CROCE', 'SONCINO'], 75],
#  [['PANDINO', 'CASALMAGGIORE'], 14],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMONA - CDA'], 1320],
#  [['BRESCIA', 'MARTIGNANA DI PO'], 133],
#  [['PIANENGO', 'SONCINO'], 56],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['SAN GIOVANNI IN CROCE', 'CREMA'], 404],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['PIADENA DRIZZONA', 'VESCOVATO'], 24],
#  [['PIADENA DRIZZONA', 'SERGNANO'], 27],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['BRESCIA', "RIVOLTA D'ADDA"], 1723],
#  [['GRONTARDO', 'CREMA'], 136],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CASTELLEONE', 'CREMONA - CDA'], 130],
#  [["SPINO D'ADDA", 'MADIGNANO'], 69],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['SONCINO', 'BRESCIA'], 325],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['MADIGNANO', 'CREMA'], 305],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['SONCINO', 'SONCINO'], 116],
#  [['PESCAROLO ED UNITI', 'RIPALTA CREMASCA'], 30],
#  [['PESCAROLO ED UNITI', 'CREMA'], 348],
#  [['PESCAROLO ED UNITI', 'BRESCIA'], 170],
#  [['PESCAROLO ED UNITI', 'CREMA'], 348],
#  [['SAN GIOVANNI IN CROCE', 'CREMA'], 404],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CREMA', 'MONTODINE'], 80],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['CREMA', 'BRESCIA'], 2540],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['BRESCIA', 'RIPALTA CREMASCA'], 994],
#  [['CREMA', 'CREMA'], 1417],
#  [['CASALMAGGIORE', 'MADIGNANO'], 104],
#  [['BRESCIA', 'CASALMAGGIORE'], 953],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'GUSSOLA'], 286],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['CASTELLEONE', 'PANDINO'], 312],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['CASTELLEONE', 'CREMA'], 1582],
#  [['CREMA', 'CREMA'], 1417],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['OFFANENGO', 'BRESCIA'], 891],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['BRESCIA', 'MADIGNANO'], 1566],
#  [['BRESCIA', 'SONCINO'], 2533],
#  [['VAILATE', 'RIPALTA CREMASCA'], 17],
#  [['BRESCIA', 'ROMANENGO'], 322],
#  [['BRESCIA', 'MARTIGNANA DI PO'], 133],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'CREMA'], 20176],
#  [['BRESCIA', 'PIADENA DRIZZONA'], 963],
#  [['BRESCIA', 'CREMONA. LA PICCOLA BIBLIOTECA'], 187],
#  [['BRESCIA', 'SOSPIRO'], 1112],
#  [['BRESCIA', 'SOSPIRO'], 1112],
#  [['BRESCIA', 'SORESINA'], 1936],
#  [['BRESCIA', 'OFFANENGO'], 3958],
#  [['UNIONE MUNICIPIA', 'CREMA'], 171],
#  [['UNIONE MUNICIPIA', 'CREMA'], 171],
#  [['UNIONE MUNICIPIA', 'OFFANENGO'], 77],
#  [['DOVERA', 'RIPALTA CREMASCA'], 27],
#  [['DOVERA', 'PANDINO'], 50],
#  [['UNIONE MUNICIPIA', 'SESTO ED UNITI'], 1],
#  [['UNIONE MUNICIPIA', "SPINO D'ADDA"], 10],
#  [['UNIONE MUNICIPIA', 'CREMA'], 171],
#  [['DOVERA', 'SOSPIRO'], 14],
#  [['RICENGO', 'BRESCIA'], 126],
#  [['RICENGO', 'CREMA'], 152],
#  [['PADERNO PONCHIELLI', 'CREMA'], 25],
#  ...]

# %%
def unique(list_): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list_: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
    return unique_list
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-e5486ef2ca04> in <module>
#      11     return unique_list
#      12
# ---> 13 s =  pd.Series(unique(occ))
#      14 s
#
# <ipython-input-30-e5486ef2ca04> in unique(list_)
#       8         # check if exists in unique_list or not
#       9         if x not in unique_list:
# ---> 10             unique_list.append(x)
#      11     return unique_list
#      12
#
# KeyboardInterrupt:

# %%
s
# Out:
# 0                       [[RIVOLTA D'ADDA, BONEMERSE], 53]
# 1                       [[RIVOLTA D'ADDA, ROMANENGO], 59]
# 2                      [[RIVOLTA D'ADDA, Agnadello], 108]
# 3                   [[RIVOLTA D'ADDA, SPINO D'ADDA], 114]
# 4                             [[BRESCIA, BONEMERSE], 404]
# 5       [[GADESCO PIEVE DELMONA, GADESCO PIEVE DELMONA...
# 6                   [[PALAZZO PIGNANO, SPINO D'ADDA], 35]
# 7                 [[PALAZZO PIGNANO, RIVOLTA D'ADDA], 18]
# 8               [[PALAZZO PIGNANO, PIADENA DRIZZONA], 25]
# 9                            [[OFFANENGO, VESCOVATO], 84]
# 10                              [[BRESCIA, RICENGO], 801]
# 11                     [[OFFANENGO, MONTE CREMASCO], 300]
# 12                           [[MONTODINE, OFFANENGO], 19]
# 13                   [[BRESCIA, PESCAROLO ED UNITI], 713]
# 14                      [[VESCOVATO, ISOLA DOVARESE], 16]
# 15                      [[VESCOVATO, MONTE CREMASCO], 36]
# 16          [[GADESCO PIEVE DELMONA, MONTE CREMASCO], 54]
# 17        [[GADESCO PIEVE DELMONA, PIADENA DRIZZONA], 29]
# 18                        [[CASALMAGGIORE, PIANENGO], 65]
# 19                       [[CASALMAGGIORE, MONTODINE], 54]
# 20                  [[CASALMAGGIORE, MONTE CREMASCO], 86]
# 21                [[CASALMAGGIORE, UFF. BIB. CREMONA], 4]
# 22                       [[CASALMAGGIORE, BONEMERSE], 36]
# 23                       [[CASALMAGGIORE, BRESCIA], 1223]
# 24                      [[CASALMAGGIORE, OFFANENGO], 266]
# 25                    [[ROMANENGO, UFF. BIB. CREMONA], 2]
# 26                             [[ROMANENGO, CAPRALBA], 9]
# 27                   [[PIZZIGHETTONE, PIZZIGHETTONE], 80]
# 28                         [[BRESCIA, SPINO D'ADDA], 791]
# 29                            [[OFFANENGO, SONCINO], 300]
#                               ...
# 3417                         [[CREMA, SAN DANIELE PO], 1]
# 3418            [[CASALE CREMASCO VIDOLASCO, OSTIANO], 1]
# 3419              [[ISOLA DOVARESE, MARTIGNANA DI PO], 1]
# 3420                              [[OSTIANO, OSTIANO], 1]
# 3421                     [[Cremona-A.R.T.E., PANDINO], 1]
# 3422       [[CASALE CREMASCO VIDOLASCO, SPINO D'ADDA], 1]
# 3423        [[FIESCO, CREMONA. LA PICCOLA BIBLIOTECA], 3]
# 3424                     [[UNIONE MUNICIPIA, TRIGOLO], 1]
# 3425                    [[SERGNANO, Cremona-A.R.T.E.], 1]
# 3426    [[MARTIGNANA DI PO, Cremona - Manin (scolastic...
# 3427             [[CORTE DE' FRATI, RIPALTA CREMASCA], 1]
# 3428                  [[CREMOSANO, TRESCORE CREMASCO], 1]
# 3429                     [[CREMOSANO, PERSICO DOSIMO], 1]
# 3430    [[CREMONA - CDA, Cremona - Manin (scolastica)]...
# 3431                           [[CAPERGNANICA, IZANO], 1]
# 3432    [[CASTELVERDE, CREMONA. LA PICCOLA BIBLIOTECA]...
# 3433                      [[CAMISANO, RIVOLTA D'ADDA], 1]
# 3434              [[RIVOLTA D'ADDA, Cremona-A.R.T.E.], 1]
# 3435                     [[Cremona-M.I.T.O., BRESCIA], 1]
# 3436             [[CORTE DE' FRATI, PIADENA DRIZZONA], 1]
# 3437          [[PESCAROLO ED UNITI, Cremona-A.R.T.E.], 1]
# 3438    [[SERGNANO, Cremona - Anguissola (scolastica)]...
# 3439               [[CORTE DE' FRATI, PERSICO DOSIMO], 1]
# 3440    [[GUSSOLA, Cremona - Anguissola (scolastica)], 2]
# 3441           [[Cremona-A.R.T.E., SOLAROLO RAINERIO], 1]
# 3442                     [[CINGIA DE' BOTTI, VAILATE], 1]
# 3443    [[MONTODINE, Cremona - Anguissola (scolastica)...
# 3444                [[RIPALTA CREMASCA, CASALBUTTANO], 1]
# 3445                   [[CAMISANO, TRESCORE CREMASCO], 1]
# 3446                [[VAILATE, GADESCO PIEVE DELMONA], 1]
# Length: 3447, dtype: object
